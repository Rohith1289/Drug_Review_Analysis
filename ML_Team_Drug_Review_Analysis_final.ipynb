# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from wordcloud import WordCloud
from textblob import TextBlob
from nltk.corpus import stopwords
from collections import Counter
import warnings; warnings.simplefilter('ignore')
import nltk
import string
from nltk import ngrams
from nltk.tokenize import word_tokenize 
from nltk.stem import SnowballStemmer

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
df_train = pd.read_csv(r"/content/drive/MyDrive/data/drugsComTrain_raw.csv")
df_test = pd.read_csv(r"/content/drive/MyDrive/data/drugsComTest_raw.csv")

# %%
df_train.dtypes
# Out:
# uniqueID        int64
# drugName       object
# condition      object
# review         object
# rating          int64
# date           object
# usefulCount     int64
# dtype: object

# %%
df_train.head()
# Out:
#    uniqueID                  drugName                     condition  \
# 0    206461                 Valsartan  Left Ventricular Dysfunction
# 1     95260                Guanfacine                          ADHD
# 2     92703                    Lybrel                 Birth Control
# 3    138000                Ortho Evra                 Birth Control
# 4     35696  Buprenorphine / naloxone             Opiate Dependence
#
#                                               review  rating       date  \
# 0  "It has no side effect, I take it in combinati...       9  20-May-12
# 1  "My son is halfway through his fourth week of ...       8  27-Apr-10
# 2  "I used to take another oral contraceptive, wh...       5  14-Dec-09
# 3  "This is my first time using any form of birth...       8   3-Nov-15
# 4  "Suboxone has completely turned my life around...       9  27-Nov-16
#
#    usefulCount
# 0           27
# 1          192
# 2           17
# 3           10
# 4           37

# %%
print ("The shape of the train set given is : ", df_train.shape)
print ("The shape of the test set given is : ", df_test.shape)
# Out:
# The shape of the train set given is :  (161297, 7)
# The shape of the test set given is :  (53766, 7)

# %%
# Droping the data points with null values
df_train = df_train.dropna(how = 'any', axis = 0)
df_test = df_test.dropna(how = 'any', axis = 0)

# %%
print ("The shape of the train df :",df_train.shape)
print ("The shape of the test df :", df_test.shape)
# Out:
# The shape of the train df : (160398, 7)
# The shape of the test df : (53471, 7)

# %%
# Merging the test and train data 
merge = [df_train, df_test]
df_data = pd.concat(merge)
df_data.head(10)
# Out:
#    uniqueID                            drugName                     condition  \
# 0    206461                           Valsartan  Left Ventricular Dysfunction
# 1     95260                          Guanfacine                          ADHD
# 2     92703                              Lybrel                 Birth Control
# 3    138000                          Ortho Evra                 Birth Control
# 4     35696            Buprenorphine / naloxone             Opiate Dependence
# 5    155963                              Cialis  Benign Prostatic Hyperplasia
# 6    165907                      Levonorgestrel       Emergency Contraception
# 7    102654                        Aripiprazole               Bipolar Disorde
# 8     74811                              Keppra                      Epilepsy
# 9     48928  Ethinyl estradiol / levonorgestrel                 Birth Control
#
#                                               review  rating       date  \
# 0  "It has no side effect, I take it in combinati...       9  20-May-12
# 1  "My son is halfway through his fourth week of ...       8  27-Apr-10
# 2  "I used to take another oral contraceptive, wh...       5  14-Dec-09
# 3  "This is my first time using any form of birth...       8   3-Nov-15
# 4  "Suboxone has completely turned my life around...       9  27-Nov-16
# 5  "2nd day on 5mg started to work with rock hard...       2  28-Nov-15
# 6  "He pulled out, but he cummed a bit in me. I t...       1   7-Mar-17
# 7  "Abilify changed my life. There is hope. I was...      10  14-Mar-15
# 8  " I Ve had  nothing but problems with the Kepp...       1   9-Aug-16
# 9  "I had been on the pill for many years. When m...       8   8-Dec-16
#
#    usefulCount
# 0           27
# 1          192
# 2           17
# 3           10
# 4           37
# 5           43
# 6            5
# 7           32
# 8           11
# 9            1

# %%
df_data.columns
# Out:
# Index(['uniqueID', 'drugName', 'condition', 'review', 'rating', 'date',
#        'usefulCount'],
#       dtype='object')

# %%
df_data.shape
# Out:
# (213869, 7)

# %%
df_data
# Out:
#        uniqueID                  drugName                     condition  \
# 0        206461                 Valsartan  Left Ventricular Dysfunction
# 1         95260                Guanfacine                          ADHD
# 2         92703                    Lybrel                 Birth Control
# 3        138000                Ortho Evra                 Birth Control
# 4         35696  Buprenorphine / naloxone             Opiate Dependence
# ...         ...                       ...                           ...
# 53761    159999                 Tamoxifen     Breast Cancer, Prevention
# 53762    140714              Escitalopram                       Anxiety
# 53763    130945            Levonorgestrel                 Birth Control
# 53764     47656                Tapentadol                          Pain
# 53765    113712                 Arthrotec                      Sciatica
#
#                                                   review  rating       date  \
# 0      "It has no side effect, I take it in combinati...       9  20-May-12
# 1      "My son is halfway through his fourth week of ...       8  27-Apr-10
# 2      "I used to take another oral contraceptive, wh...       5  14-Dec-09
# 3      "This is my first time using any form of birth...       8   3-Nov-15
# 4      "Suboxone has completely turned my life around...       9  27-Nov-16
# ...                                                  ...     ...        ...
# 53761  "I have taken Tamoxifen for 5 years. Side effe...      10  13-Sep-14
# 53762  "I&#039;ve been taking Lexapro (escitaploprgra...       9   8-Oct-16
# 53763  "I&#039;m married, 34 years old and I have no ...       8  15-Nov-10
# 53764  "I was prescribed Nucynta for severe neck/shou...       1  28-Nov-11
# 53765                                      "It works!!!"       9  13-Sep-09
#
#        usefulCount
# 0               27
# 1              192
# 2               17
# 3               10
# 4               37
# ...            ...
# 53761           43
# 53762           11
# 53763            7
# 53764           20
# 53765           46
#
# [213869 rows x 7 columns]

# %%
df_data.columns = df_data.columns.str.lower()

# %%
# Sorting the dataframe
df_data.sort_values(['uniqueid'], ascending = True, inplace = True)
df_data.reset_index(drop = True, inplace = True)

# %%
df_data['condition'].isnull().sum(axis = 0)
# Out:
# 0

# %%
df_data.dtypes
# Out:
# uniqueid        int64
# drugname       object
# condition      object
# review         object
# rating          int64
# date           object
# usefulcount     int64
# dtype: object

# %%
df_data.head(10)
# Out:
#    uniqueid             drugname                  condition  \
# 0         0  Medroxyprogesterone  Abnormal Uterine Bleeding
# 1         2  Medroxyprogesterone                 Amenorrhea
# 2         3  Medroxyprogesterone  Abnormal Uterine Bleeding
# 3         4  Medroxyprogesterone              Birth Control
# 4         5  Medroxyprogesterone  Abnormal Uterine Bleeding
# 5         6  Medroxyprogesterone              Birth Control
# 6         7  Medroxyprogesterone  Abnormal Uterine Bleeding
# 7         8  Medroxyprogesterone  Abnormal Uterine Bleeding
# 8         9  Medroxyprogesterone  Abnormal Uterine Bleeding
# 9        10  Medroxyprogesterone  Abnormal Uterine Bleeding
#
#                                               review  rating       date  \
# 0  "Been on the depo injection since January 2015...       3  28-Oct-15
# 1  "I&#039;m 21 years old and recently found out ...      10  27-Oct-15
# 2  "I have been on the shot 11 years and until a ...       8  27-Oct-15
# 3  "Ive had four shots at this point. I was on bi...       9  26-Oct-15
# 4  "I had a total of 3 shots. I got my first one ...       1  25-Oct-15
# 5  "This is a horrible shot!! I got my first shot...       1  24-Oct-15
# 6  "I&#039;m 18 and got this for heavy bleeding. ...       5  22-Oct-15
# 7  "Im 19 and have been having heavy and painful ...       5  21-Oct-15
# 8  "I&#039;m a 30 year old woman. I got the shot ...       2  21-Oct-15
# 9  "I&#039;m 17 years old and I got shot in Augus...       7  20-Oct-15
#
#    usefulcount
# 0            4
# 1           11
# 2            7
# 3           12
# 4            4
# 5            3
# 6            6
# 7            2
# 8            5
# 9            2

# %%
df_data['condition'].nunique() #unique tuple values
# Out:
# 916

# %%
df_data.loc[df_data['rating'] == 1, :]['drugname'].value_counts()
# Out:
# Miconazole                           767
# Ethinyl estradiol / norethindrone    728
# Etonogestrel                         707
# Levonorgestrel                       511
# Nexplanon                            504
#                                     ...
# Topical Anesthetic Dental Gel          1
# Colyte                                 1
# Vitamin B2                             1
# Atovaquone                             1
# Nutropin                               1
# Name: drugname, Length: 1916, dtype: int64

# %%
df_data.loc[df_data['rating'] == 0, :].shape
# Out:
# (0, 7)

# %%
df_data.head(10)
# Out:
#    uniqueid             drugname                  condition  \
# 0         0  Medroxyprogesterone  Abnormal Uterine Bleeding
# 1         2  Medroxyprogesterone                 Amenorrhea
# 2         3  Medroxyprogesterone  Abnormal Uterine Bleeding
# 3         4  Medroxyprogesterone              Birth Control
# 4         5  Medroxyprogesterone  Abnormal Uterine Bleeding
# 5         6  Medroxyprogesterone              Birth Control
# 6         7  Medroxyprogesterone  Abnormal Uterine Bleeding
# 7         8  Medroxyprogesterone  Abnormal Uterine Bleeding
# 8         9  Medroxyprogesterone  Abnormal Uterine Bleeding
# 9        10  Medroxyprogesterone  Abnormal Uterine Bleeding
#
#                                               review  rating       date  \
# 0  "Been on the depo injection since January 2015...       3  28-Oct-15
# 1  "I&#039;m 21 years old and recently found out ...      10  27-Oct-15
# 2  "I have been on the shot 11 years and until a ...       8  27-Oct-15
# 3  "Ive had four shots at this point. I was on bi...       9  26-Oct-15
# 4  "I had a total of 3 shots. I got my first one ...       1  25-Oct-15
# 5  "This is a horrible shot!! I got my first shot...       1  24-Oct-15
# 6  "I&#039;m 18 and got this for heavy bleeding. ...       5  22-Oct-15
# 7  "Im 19 and have been having heavy and painful ...       5  21-Oct-15
# 8  "I&#039;m a 30 year old woman. I got the shot ...       2  21-Oct-15
# 9  "I&#039;m 17 years old and I got shot in Augus...       7  20-Oct-15
#
#    usefulcount
# 0            4
# 1           11
# 2            7
# 3           12
# 4            4
# 5            3
# 6            6
# 7            2
# 8            5
# 9            2

# %%
df_data.describe()
# Out:
#             uniqueid         rating    usefulcount
# count  213869.000000  213869.000000  213869.000000
# mean   116076.924786       6.991149      28.094118
# std     67016.705794       3.275792      36.401377
# min         0.000000       1.000000       0.000000
# 25%     58122.000000       5.000000       6.000000
# 50%    115972.000000       8.000000      16.000000
# 75%    174018.000000      10.000000      36.000000
# max    232291.000000      10.000000    1291.000000

# %%
# Converting the date in to date time format
df_data['date'] = pd.to_datetime(df_data['date'])
df_data.head()
# Out:
#    uniqueid             drugname                  condition  \
# 0         0  Medroxyprogesterone  Abnormal Uterine Bleeding
# 1         2  Medroxyprogesterone                 Amenorrhea
# 2         3  Medroxyprogesterone  Abnormal Uterine Bleeding
# 3         4  Medroxyprogesterone              Birth Control
# 4         5  Medroxyprogesterone  Abnormal Uterine Bleeding
#
#                                               review  rating       date  \
# 0  "Been on the depo injection since January 2015...       3 2015-10-28
# 1  "I&#039;m 21 years old and recently found out ...      10 2015-10-27
# 2  "I have been on the shot 11 years and until a ...       8 2015-10-27
# 3  "Ive had four shots at this point. I was on bi...       9 2015-10-26
# 4  "I had a total of 3 shots. I got my first one ...       1 2015-10-25
#
#    usefulcount
# 0            4
# 1           11
# 2            7
# 3           12
# 4            4

# %% [markdown]
# ### Exploratory Data Analysis

# %%
# This barplot shows the top 20 drugs with the 10/10 rating
import seaborn as sns

# Setting the Parameter
sns.set(font_scale = 1.2, style = 'darkgrid')
plt.rcParams['figure.figsize'] = [15, 8]

rating = dict(df_data.loc[df_data.rating == 10, "drugname"].value_counts())
drugname = list(rating.keys())
drug_rating = list(rating.values())

sns_rating = sns.barplot(x = drugname[0:20], y = drug_rating[0:20])

sns_rating.set_title('Top 20 drugs with 10/10 rating')
sns_rating.set_ylabel("Number of Ratings")
sns_rating.set_xlabel("Drug Names")
plt.setp(sns_rating.get_xticklabels(), rotation=90);

# %%
# This barplot shows the Top 20 drugs with the 1/10 rating
import seaborn as sns

# Setting the Parameter
sns.set(font_scale = 1.2, style = 'whitegrid')
plt.rcParams['figure.figsize'] = [15, 8]

rating = dict(df_data.loc[df_data.rating == 1, "drugname"].value_counts())
drugname = list(rating.keys())
drug_rating = list(rating.values())

sns_rating = sns.barplot(x = drugname[0:20], y = drug_rating[0:20], palette = 'winter')

sns_rating.set_title('Top 20 drugs with 1/10 rating')
sns_rating.set_ylabel("Number of Ratings")
sns_rating.set_xlabel("Drug Names")
plt.setp(sns_rating.get_xticklabels(), rotation=90);

# %%
# Word cloud of the reviews with rating equal to 10
df_rate_ten = df_data.loc[df_data.rating == 10, 'review']
k = (' '.join(df_rate_ten))

wordcloud = WordCloud(width = 1000, height = 500).generate(k)
plt.figure(figsize=(15, 10))
plt.imshow(wordcloud)
plt.axis('off');

# %%
# Word cloud of the reviews with rating equal to 1
df_rate_one = df_data.loc[df_data.rating == 1, 'review']
k1 = (' '.join(df_rate_one))

wordcloud = WordCloud(width = 1000, height = 500).generate(k1)
plt.figure(figsize=(15, 10))
plt.imshow(wordcloud)
plt.axis('off');

# %%
# This barplot shows the mean rating per year

mean_rating = dict(df_data.groupby(df_data['date'].dt.year)['rating'].mean())
plt.rcParams['figure.figsize'] = [12, 7]
sns.set(font_scale = 1.2, style = 'whitegrid')
sns_ = sns.barplot(x = list(mean_rating.keys()), y = list(mean_rating.values()), color = 'slateblue');
sns_.set_xlabel('Year')
sns_.set_ylabel('Rating');

# %%
# This barplot show the top 10 conditions the people are suffering.
cond = dict(df_data['condition'].value_counts())
top_condition = list(cond.keys())[0:10]
values = list(cond.values())[0:10]
sns.set(style = 'darkgrid', font_scale = 1.3)
plt.rcParams['figure.figsize'] = [18, 7]

sns_ = sns.barplot(x = top_condition, y = values, palette = 'winter')
sns_.set_title("Top 10 conditions")
sns_.set_xlabel("Conditions")
sns_.set_ylabel("Count");

# %%
# Top 10 drugs which are used for the top condition, that is Birth Control
df = df_data[df_data['condition'] == 'Birth Control']['drugname'].value_counts()[0: 10]
sns.set(font_scale = 1.2, style = 'darkgrid')

sns_ = sns.barplot(x = df.index, y = df.values, palette = 'summer')
sns_.set_xlabel('Drug Names')
sns_.set_title("Top 10 Drugs used for Birth Control")
plt.setp(sns_.get_xticklabels(), rotation = 90);

# %%
# Distribution of the useful count
sns.set(style = 'whitegrid', font_scale = 1.3)
plt.rcParams['figure.figsize'] = [12, 7]
sns.distplot(df_data['usefulcount'].dropna())
# Out:
# <Axes: xlabel='usefulcount', ylabel='Density'>

# %%
# This barplot shows the number of reviews per year
df = df_data['date'].dt.year.value_counts()
df = df.sort_index()

sns_ = sns.barplot(x = df.index, y = df.values, color = 'mediumaquamarine')
sns_.set_title("Number of reviews per year")
sns_.set_xlabel("Year");

# %%
# Heatmap of the correlation matrix
plt.rcParams['figure.figsize'] = [7,5]
sns.set(font_scale = 1.2)
corr = df_data.select_dtypes(include = 'int64').corr()
sns_heat = sns.heatmap(corr, annot = True, vmin=-1, vmax=1, center=0,
            cmap=sns.diverging_palette(20, 220, n=200), square=True);
plt.setp(sns_heat.get_xticklabels(), rotation = 45);

# %%
df_data.head()
# Out:
#    uniqueid             drugname                  condition  \
# 0         0  Medroxyprogesterone  Abnormal Uterine Bleeding
# 1         2  Medroxyprogesterone                 Amenorrhea
# 2         3  Medroxyprogesterone  Abnormal Uterine Bleeding
# 3         4  Medroxyprogesterone              Birth Control
# 4         5  Medroxyprogesterone  Abnormal Uterine Bleeding
#
#                                               review  rating       date  \
# 0  "Been on the depo injection since January 2015...       3 2015-10-28
# 1  "I&#039;m 21 years old and recently found out ...      10 2015-10-27
# 2  "I have been on the shot 11 years and until a ...       8 2015-10-27
# 3  "Ive had four shots at this point. I was on bi...       9 2015-10-26
# 4  "I had a total of 3 shots. I got my first one ...       1 2015-10-25
#
#    usefulcount
# 0            4
# 1           11
# 2            7
# 3           12
# 4            4

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
# Top 20 unigrams according to the rating
df_ = df_data[['rating', 'review']]
df_['review'] = df_data['review'].str.replace("&#039;", "")
df_['review'] = df_['review'].str.replace(r'[^\w\d\s]',' ') 

df_review_5 = " ".join(df_.loc[df_.rating <= 5, 'review'])
df_review_10 = " ".join(df_.loc[df_.rating > 5, 'review'])

token_review_5 = word_tokenize(df_review_5)
token_review_10 = word_tokenize(df_review_10)

unigrams_5 = ngrams(token_review_5, 1)
unigrams_10 = ngrams(token_review_10, 1)

frequency_5 = Counter(unigrams_5)
frequency_10 = Counter(unigrams_10)

df_5 = pd.DataFrame(frequency_5.most_common(20))
df_10 = pd.DataFrame(frequency_10.most_common(20))

# Barplot that shows the top 20 unigrams
plt.rcParams['figure.figsize'] = [20,11]
fig, ax = plt.subplots(1,2)
sns.set(font_scale = 1.5, style = 'whitegrid')

sns_5 = sns.barplot(x = df_5[1], y = df_5[0], color = 'lightsteelblue', ax = ax[0])
sns_10 = sns.barplot(x = df_10[1], y = df_10[0], color = 'lightsteelblue', ax = ax[1])

# Setting axes labels
sns_5.set_title("Top 20 unigrams according for rating <= 5")
sns_10.set_title("Top 20 unigrams according for rating > 5")
sns_5.set_ylabel("Unigrams");

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
# Top 20 bigrams according to the rating
bigrams_5 = ngrams(token_review_5, 2)
bigrams_10 = ngrams(token_review_10, 2)

frequency_5 = Counter(bigrams_5)
frequency_10 = Counter(bigrams_10)

df_5 = pd.DataFrame(frequency_5.most_common(20))
df_10 = pd.DataFrame(frequency_10.most_common(20))

# Barplot that shows the top 20 bigrams
plt.rcParams['figure.figsize'] = [22,11]
fig, ax = plt.subplots(1,2)
sns.set(font_scale = 1.3, style = 'whitegrid')

sns_5 = sns.barplot(x = df_5[1], y = df_5[0], color = 'red', ax = ax[0])
sns_10 = sns.barplot(x = df_10[1], y = df_10[0], color = 'red', ax = ax[1])

# Setting axes labels
sns_5.set_title("Top 20 bigrams according for rating <= 5")
sns_10.set_title("Top 20 bigrams according for rating > 5")
sns_5.set_ylabel("bigrams");

# %%
# Top 20 trigrams according to the rating
trigrams_5 = ngrams(token_review_5, 3)
trigrams_10 = ngrams(token_review_10, 3)

frequency_5 = Counter(trigrams_5)
frequency_10 = Counter(trigrams_10)

df_5 = pd.DataFrame(frequency_5.most_common(20))
df_10 = pd.DataFrame(frequency_10.most_common(20))

# Barplot that shows the top 20 trigrams
plt.rcParams['figure.figsize'] = [25,13]
fig, ax = plt.subplots(1,2)
sns.set(font_scale = 1.3, style = 'whitegrid')

sns_5 = sns.barplot(x = df_5[1], y = df_5[0], color = 'orange', ax = ax[0])
sns_10 = sns.barplot(x = df_10[1], y = df_10[0], color = 'orange', ax = ax[1])

# Setting axes labels
sns_5.set_title("Top 20 trigrams according for rating <= 5")
sns_10.set_title("Top 20 trigrams according for rating > 5")
sns_5.set_ylabel("trigrams");

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
# Word count plot

# Removing the stop words before plotting
stop_words = set(stopwords.words('english'))
df_['review'] = df_['review'].str.lower()
df_['review_1'] = df_['review'].apply(lambda x: " ".join(word for word in x.split() if word not in stop_words))
df_review = " ".join(df_['review_1'])
tokenize = word_tokenize(df_review)
frequency = Counter(tokenize)
df = pd.DataFrame(frequency.most_common(30))

plt.rcParams['figure.figsize'] = [12, 15]
sns.set(font_scale = 1.3, style = 'whitegrid')

# plotting
word_count = sns.barplot(x = df[1], y = df[0], color = 'darkcyan')
word_count.set_title("Word Count Plot")
word_count.set_ylabel("Words")
word_count.set_xlabel("Count");

# %% [markdown]
# ### Preprocessing the reviews for the best polarity and classification

# %%
# Giving the Sentiment according to the ratings
df_data['sentiment_rate'] = df_data['rating'].apply(lambda x: 1 if x > 5 else 0)

# %%
def review_clean(review): 
    # changing to lower case
    lower = review.str.lower()
    
    # Replacing the repeating pattern of &#039;
    pattern_remove = lower.str.replace("&#039;", "")
    
    # Removing all the special Characters
    special_remove = pattern_remove.str.replace(r'[^\w\d\s]',' ')
    
    # Removing all the non ASCII characters
    ascii_remove = special_remove.str.replace(r'[^\x00-\x7F]+',' ')
    
    # Removing the leading and trailing Whitespaces
    whitespace_remove = ascii_remove.str.replace(r'^\s+|\s+?$','')
    
    # Replacing multiple Spaces with Single Space
    multiw_remove = whitespace_remove.str.replace(r'\s+',' ')
    
    # Replacing Two or more dots with one
    dataframe = multiw_remove.str.replace(r'\.{2,}', ' ')
    
    return dataframe

# %%
#df_data['review_clean'] = df_data['review'].apply(review_clean)
df_data['review_clean'] = review_clean(df_data['review'])

# %%
# Removing the stopwords
stop_words = set(stopwords.words('english'))
df_data['review_clean'] = df_data['review_clean'].apply(lambda x: ' '.join(word for word in x.split() if word not in stop_words))

# %%
# Removing the word stems using the Snowball Stemmer
Snow_ball = SnowballStemmer("english")
df_data['review_clean'] = df_data['review_clean'].apply(lambda x: " ".join(Snow_ball.stem(word) for word in x.split()))

# %%
df_data['review_clean'][0: 20]
# Out:
# 0     depo inject sinc januari 2015 bleed stop anoth...
# 1     im 21 year old recent found might pcos havent ...
# 2     shot 11 year month ago never 1 period even spo...
# 3     ive four shot point birth control pill year du...
# 4     total 3 shot got first one leav hospit give bi...
# 5     horribl shot got first shot august ever sinc e...
# 6     im 18 got heavi bleed ive alway heard bc make ...
# 7     im 19 heavi pain period sinc forev got depo sh...
# 8     im 30 year old woman got shot august 9th bleed...
# 9     im 17 year old got shot august 2015 person don...
# 10    first month awesom absolut wonder start light ...
# 11    start depo shot year ago origin bled 3 week da...
# 12    im 24 ive 2 year quit period last 3 week first...
# 13    im 17 went depo heavi bleed like heavi would g...
# 14    love conveni one shot everi three month look b...
# 15    1st shot sept 2nd nonstop bleed sinc side effe...
# 16    took shot safe im young teenag sexual activ bi...
# 17    ive shot 2 year amp one complaint skin couldnt...
# 18    oh man first shot great minim bleed second sho...
# 19    got shot 6 week post partum nurs seen high rec...
# Name: review_clean, dtype: object

# %%
# Separating the day, month and year from the Date
df_data['day'] = df_data['date'].dt.day
df_data['month'] = df_data['date'].dt.month
df_data['year'] = df_data['date'].dt.year

# %%
df_data.head()
# Out:
#    uniqueid             drugname                  condition  \
# 0         0  Medroxyprogesterone  Abnormal Uterine Bleeding
# 1         2  Medroxyprogesterone                 Amenorrhea
# 2         3  Medroxyprogesterone  Abnormal Uterine Bleeding
# 3         4  Medroxyprogesterone              Birth Control
# 4         5  Medroxyprogesterone  Abnormal Uterine Bleeding
#
#                                               review  rating       date  \
# 0  "Been on the depo injection since January 2015...       3 2015-10-28
# 1  "I&#039;m 21 years old and recently found out ...      10 2015-10-27
# 2  "I have been on the shot 11 years and until a ...       8 2015-10-27
# 3  "Ive had four shots at this point. I was on bi...       9 2015-10-26
# 4  "I had a total of 3 shots. I got my first one ...       1 2015-10-25
#
#    usefulcount  sentiment_rate  \
# 0            4               0
# 1           11               1
# 2            7               1
# 3           12               1
# 4            4               0
#
#                                         review_clean  day  month  year
# 0  depo inject sinc januari 2015 bleed stop anoth...   28     10  2015
# 1  im 21 year old recent found might pcos havent ...   27     10  2015
# 2  shot 11 year month ago never 1 period even spo...   27     10  2015
# 3  ive four shot point birth control pill year du...   26     10  2015
# 4  total 3 shot got first one leav hospit give bi...   25     10  2015

# %%
def sentiment(review):
    # Sentiment polarity of the reviews
    pol = []
    for i in review:
        analysis = TextBlob(i)
        pol.append(analysis.sentiment.polarity)
    return pol

# %%
df_data.head()
# Out:
#    uniqueid             drugname                  condition  \
# 0         0  Medroxyprogesterone  Abnormal Uterine Bleeding
# 1         2  Medroxyprogesterone                 Amenorrhea
# 2         3  Medroxyprogesterone  Abnormal Uterine Bleeding
# 3         4  Medroxyprogesterone              Birth Control
# 4         5  Medroxyprogesterone  Abnormal Uterine Bleeding
#
#                                               review  rating       date  \
# 0  "Been on the depo injection since January 2015...       3 2015-10-28
# 1  "I&#039;m 21 years old and recently found out ...      10 2015-10-27
# 2  "I have been on the shot 11 years and until a ...       8 2015-10-27
# 3  "Ive had four shots at this point. I was on bi...       9 2015-10-26
# 4  "I had a total of 3 shots. I got my first one ...       1 2015-10-25
#
#    usefulcount  sentiment_rate  \
# 0            4               0
# 1           11               1
# 2            7               1
# 3           12               1
# 4            4               0
#
#                                         review_clean  day  month  year
# 0  depo inject sinc januari 2015 bleed stop anoth...   28     10  2015
# 1  im 21 year old recent found might pcos havent ...   27     10  2015
# 2  shot 11 year month ago never 1 period even spo...   27     10  2015
# 3  ive four shot point birth control pill year du...   26     10  2015
# 4  total 3 shot got first one leav hospit give bi...   25     10  2015

# %%
df_data['sentiment'] = sentiment(df_data['review'])

# %%
df_data['sentiment_clean'] = sentiment(df_data['review_clean'])

# %% [markdown]
# The Correlation coefficient between the sentiment of the uncleaned review with rating is greater than the cleaned review, so now lets try without the snowball stemmer and without removing the stopwords.

# %%
np.corrcoef(df_data['sentiment'], df_data['rating'])
# Out:
# array([[1.       , 0.3481753],
#        [0.3481753, 1.       ]])

# %%
np.corrcoef(df_data['sentiment_clean'], df_data['rating'])
# Out:
# array([[1.        , 0.23328393],
#        [0.23328393, 1.        ]])

# %%
# Cleaning the reviews without removing the stop words and using snowball stemmer
df_data['review_clean_ss'] = review_clean(df_data['review'])
df_data['sentiment_clean_ss'] = sentiment(df_data['review_clean_ss'])

# %%
np.corrcoef(df_data['sentiment_clean_ss'], df_data['rating'])
# Out:
# array([[1.        , 0.34600369],
#        [0.34600369, 1.        ]])

# %%
df_data['condition'].value_counts().head(20)
# Out:
# Birth Control                38436
# Depression                   12164
# Pain                          8245
# Anxiety                       7812
# Acne                          7435
# Bipolar Disorde               5604
# Insomnia                      4904
# Weight Loss                   4857
# Obesity                       4757
# ADHD                          4509
# Diabetes, Type 2              3362
# Emergency Contraception       3290
# High Blood Pressure           3104
# Vaginal Yeast Infection       3085
# Abnormal Uterine Bleeding     2744
# Bowel Preparation             2498
# Smoking Cessation             2440
# ibromyalgia                   2370
# Migraine                      2277
# Anxiety and Stress            2236
# Name: condition, dtype: int64

# %%
df_data.head(10)
# Out:
#    uniqueid             drugname                  condition  \
# 0         0  Medroxyprogesterone  Abnormal Uterine Bleeding
# 1         2  Medroxyprogesterone                 Amenorrhea
# 2         3  Medroxyprogesterone  Abnormal Uterine Bleeding
# 3         4  Medroxyprogesterone              Birth Control
# 4         5  Medroxyprogesterone  Abnormal Uterine Bleeding
# 5         6  Medroxyprogesterone              Birth Control
# 6         7  Medroxyprogesterone  Abnormal Uterine Bleeding
# 7         8  Medroxyprogesterone  Abnormal Uterine Bleeding
# 8         9  Medroxyprogesterone  Abnormal Uterine Bleeding
# 9        10  Medroxyprogesterone  Abnormal Uterine Bleeding
#
#                                               review  rating       date  \
# 0  "Been on the depo injection since January 2015...       3 2015-10-28
# 1  "I&#039;m 21 years old and recently found out ...      10 2015-10-27
# 2  "I have been on the shot 11 years and until a ...       8 2015-10-27
# 3  "Ive had four shots at this point. I was on bi...       9 2015-10-26
# 4  "I had a total of 3 shots. I got my first one ...       1 2015-10-25
# 5  "This is a horrible shot!! I got my first shot...       1 2015-10-24
# 6  "I&#039;m 18 and got this for heavy bleeding. ...       5 2015-10-22
# 7  "Im 19 and have been having heavy and painful ...       5 2015-10-21
# 8  "I&#039;m a 30 year old woman. I got the shot ...       2 2015-10-21
# 9  "I&#039;m 17 years old and I got shot in Augus...       7 2015-10-20
#
#    usefulcount  sentiment_rate  \
# 0            4               0
# 1           11               1
# 2            7               1
# 3           12               1
# 4            4               0
# 5            3               0
# 6            6               0
# 7            2               0
# 8            5               0
# 9            2               1
#
#                                         review_clean  day  month  year  \
# 0  depo inject sinc januari 2015 bleed stop anoth...   28     10  2015
# 1  im 21 year old recent found might pcos havent ...   27     10  2015
# 2  shot 11 year month ago never 1 period even spo...   27     10  2015
# 3  ive four shot point birth control pill year du...   26     10  2015
# 4  total 3 shot got first one leav hospit give bi...   25     10  2015
# 5  horribl shot got first shot august ever sinc e...   24     10  2015
# 6  im 18 got heavi bleed ive alway heard bc make ...   22     10  2015
# 7  im 19 heavi pain period sinc forev got depo sh...   21     10  2015
# 8  im 30 year old woman got shot august 9th bleed...   21     10  2015
# 9  im 17 year old got shot august 2015 person don...   20     10  2015
#
#    sentiment  sentiment_clean  \
# 0  -0.287798        -0.127381
# 1   0.175357         0.161429
# 2  -0.210000         0.233333
# 3  -0.022500         0.069444
# 4   0.044872         0.103333
# 5   0.000321         0.013235
# 6  -0.056692         0.098052
# 7   0.030995         0.068750
# 8   0.265309         0.288889
# 9  -0.047222        -0.022500
#
#                                      review_clean_ss  sentiment_clean_ss
# 0  been on the depo injection since january 2015 ...           -0.160714
# 1  im 21 years old and recently found out i might...            0.175357
# 2  i have been on the shot 11 years and until a m...           -0.210000
# 3  ive had four shots at this point i was on birt...           -0.033333
# 4  i had a total of 3 shots i got my first one be...            0.044872
# 5  this is a horrible shot i got my first shot in...            0.000321
# 6  im 18 and got this for heavy bleeding ive alwa...           -0.065025
# 7  im 19 and have been having heavy and painful p...            0.026923
# 8  im a 30 year old woman i got the shot on augus...            0.265309
# 9  im 17 years old and i got shot in august 2015 ...           -0.047222

# %% [markdown]
# ### Feature Engineering

# %%
#Word count in each review
df_data['count_word']=df_data["review_clean_ss"].apply(lambda x: len(str(x).split()))

#Unique word count 
df_data['count_unique_word']=df_data["review_clean_ss"].apply(lambda x: len(set(str(x).split())))

#Letter count
df_data['count_letters']=df_data["review_clean_ss"].apply(lambda x: len(str(x)))

#punctuation count
df_data["count_punctuations"] = df_data["review"].apply(lambda x: len([c for c in str(x) if c in string.punctuation]))

#upper case words count
df_data["count_words_upper"] = df_data["review"].apply(lambda x: len([w for w in str(x).split() if w.isupper()]))

#title case words count
df_data["count_words_title"] = df_data["review"].apply(lambda x: len([w for w in str(x).split() if w.istitle()]))

#Number of stopwords
df_data["count_stopwords"] = df_data["review"].apply(lambda x: len([w for w in str(x).lower().split() if w in stop_words]))

#Average length of the words
df_data["mean_word_len"] = df_data["review_clean_ss"].apply(lambda x: np.mean([len(w) for w in str(x).split()]))

# %%
df_data.columns
# Out:
# Index(['uniqueid', 'drugname', 'condition', 'review', 'rating', 'date',
#        'usefulcount', 'sentiment_rate', 'review_clean', 'day', 'month', 'year',
#        'sentiment', 'sentiment_clean', 'review_clean_ss', 'sentiment_clean_ss',
#        'count_word', 'count_unique_word', 'count_letters',
#        'count_punctuations', 'count_words_upper', 'count_words_title',
#        'count_stopwords', 'mean_word_len'],
#       dtype='object')

# %%
df_data.head()
# Out:
#    uniqueid             drugname                  condition  \
# 0         0  Medroxyprogesterone  Abnormal Uterine Bleeding
# 1         2  Medroxyprogesterone                 Amenorrhea
# 2         3  Medroxyprogesterone  Abnormal Uterine Bleeding
# 3         4  Medroxyprogesterone              Birth Control
# 4         5  Medroxyprogesterone  Abnormal Uterine Bleeding
#
#                                               review  rating       date  \
# 0  "Been on the depo injection since January 2015...       3 2015-10-28
# 1  "I&#039;m 21 years old and recently found out ...      10 2015-10-27
# 2  "I have been on the shot 11 years and until a ...       8 2015-10-27
# 3  "Ive had four shots at this point. I was on bi...       9 2015-10-26
# 4  "I had a total of 3 shots. I got my first one ...       1 2015-10-25
#
#    usefulcount  sentiment_rate  \
# 0            4               0
# 1           11               1
# 2            7               1
# 3           12               1
# 4            4               0
#
#                                         review_clean  day  ...  \
# 0  depo inject sinc januari 2015 bleed stop anoth...   28  ...
# 1  im 21 year old recent found might pcos havent ...   27  ...
# 2  shot 11 year month ago never 1 period even spo...   27  ...
# 3  ive four shot point birth control pill year du...   26  ...
# 4  total 3 shot got first one leav hospit give bi...   25  ...
#
#                                      review_clean_ss  sentiment_clean_ss  \
# 0  been on the depo injection since january 2015 ...           -0.160714
# 1  im 21 years old and recently found out i might...            0.175357
# 2  i have been on the shot 11 years and until a m...           -0.210000
# 3  ive had four shots at this point i was on birt...           -0.033333
# 4  i had a total of 3 shots i got my first one be...            0.044872
#
#    count_word  count_unique_word count_letters  count_punctuations  \
# 0         101                 75           543                  31
# 1         103                 76           547                  26
# 2          59                 45           279                  12
# 3         146                 94           732                  21
# 4         152                102           728                  21
#
#    count_words_upper  count_words_title  count_stopwords  mean_word_len
# 0                  6                 14               45       4.386139
# 1                  5                 13               39       4.320388
# 2                  4                  5               28       3.745763
# 3                  4                 12               74       4.020548
# 4                 13                 20               79       3.796053
#
# [5 rows x 24 columns]

# %%
# Correlation Heatmap of the features engineered
plt.rcParams['figure.figsize'] = [17,15]
sns.set(font_scale = 1.2)
corr = df_data.select_dtypes(include = 'int64').corr()
sns_ = sns.heatmap(corr, annot = True, cmap = 'YlGnBu')
plt.setp(sns_.get_xticklabels(), rotation = 45);

# %%
# Label Encoding Drugname and Conditions
from sklearn.preprocessing import LabelEncoder
label_encoder_feat = {}
for feature in ['drugname', 'condition']:
    label_encoder_feat[feature] = LabelEncoder()
    df_data[feature] = label_encoder_feat[feature].fit_transform(df_data[feature])

# %%
df_data.head()
# Out:
#    uniqueid  drugname  condition  \
# 0         0      2043         84
# 1         2      2043        110
# 2         3      2043         84
# 3         4      2043        175
# 4         5      2043         84
#
#                                               review  rating       date  \
# 0  "Been on the depo injection since January 2015...       3 2015-10-28
# 1  "I&#039;m 21 years old and recently found out ...      10 2015-10-27
# 2  "I have been on the shot 11 years and until a ...       8 2015-10-27
# 3  "Ive had four shots at this point. I was on bi...       9 2015-10-26
# 4  "I had a total of 3 shots. I got my first one ...       1 2015-10-25
#
#    usefulcount  sentiment_rate  \
# 0            4               0
# 1           11               1
# 2            7               1
# 3           12               1
# 4            4               0
#
#                                         review_clean  day  ...  \
# 0  depo inject sinc januari 2015 bleed stop anoth...   28  ...
# 1  im 21 year old recent found might pcos havent ...   27  ...
# 2  shot 11 year month ago never 1 period even spo...   27  ...
# 3  ive four shot point birth control pill year du...   26  ...
# 4  total 3 shot got first one leav hospit give bi...   25  ...
#
#                                      review_clean_ss  sentiment_clean_ss  \
# 0  been on the depo injection since january 2015 ...           -0.160714
# 1  im 21 years old and recently found out i might...            0.175357
# 2  i have been on the shot 11 years and until a m...           -0.210000
# 3  ive had four shots at this point i was on birt...           -0.033333
# 4  i had a total of 3 shots i got my first one be...            0.044872
#
#    count_word  count_unique_word count_letters  count_punctuations  \
# 0         101                 75           543                  31
# 1         103                 76           547                  26
# 2          59                 45           279                  12
# 3         146                 94           732                  21
# 4         152                102           728                  21
#
#    count_words_upper  count_words_title  count_stopwords  mean_word_len
# 0                  6                 14               45       4.386139
# 1                  5                 13               39       4.320388
# 2                  4                  5               28       3.745763
# 3                  4                 12               74       4.020548
# 4                 13                 20               79       3.796053
#
# [5 rows x 24 columns]

# %% [markdown]
# ### Modelling

# %%
# Importing Libraries for the Machine Learning Model
from xgboost import XGBClassifier
from lightgbm import LGBMModel,LGBMClassifier, plot_importance
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report
from sklearn.model_selection import train_test_split

# %%
# Defining Features and splitting the data as train and test set

features = df_data[['condition', 'usefulcount', 'sentiment', 'day', 'month', 'year',
                   'sentiment_clean_ss', 'count_word', 'count_unique_word', 'count_letters',
                   'count_punctuations', 'count_words_upper', 'count_words_title',
                   'count_stopwords', 'mean_word_len']]

target = df_data['sentiment_rate']

X_train, X_test, y_train, y_test = train_test_split(features, target, test_size = 0.3, random_state = 42)
print ("The Train set size ", X_train.shape)
print ("The Test set size ", X_test.shape)
# Out:
# The Train set size  (149708, 15)
# The Test set size  (64161, 15)

# %% [markdown]
# Model - I LightGBM

# %%
# Training Model - I
clf = LGBMClassifier(
        n_estimators=10000,
        learning_rate=0.10,
        num_leaves=30,
        subsample=.9,
        max_depth=7,
        reg_alpha=.1,
        reg_lambda=.1,
        min_split_gain=.01,
        min_child_weight=2,
        silent=-1,
        verbose=-1,
        )
model = clf.fit(X_train, y_train)

# Predictions
predictions = model.predict(X_test)
print ("The Accuracy of the model is : ", accuracy_score(y_test, predictions))
print ("The confusion Matrix is ")
confusion_matrix(y_test, predictions)
# Out:
# The Accuracy of the model is :  0.888935646264865
# The confusion Matrix is
# array([[14800,  4545],
#        [ 2581, 42235]])

# %%
# Feature Importance Plot using LGBM
plt.rcParams['figure.figsize'] = [12, 9]
sns.set(style = 'whitegrid', font_scale = 1.2)
plot_importance(model);

# %% [markdown]
# Model - II XGBClassifier

# %%
# Training Model - II
from xgboost import plot_importance
xgb_clf = XGBClassifier(n_estimator = 10000,
                    learning_rate=0.10,
                    num_leaves=30)

model_xgb = xgb_clf.fit(X_train, y_train)

# Predictions
predictions_2 = model_xgb.predict(X_test)
print ("The Accuracy of the model is : ", accuracy_score(y_test, predictions_2))
print ("The confusion Matrix is ")
confusion_matrix(y_test, predictions_2)
# Out:
# [22:40:05] WARNING: ../src/learner.cc:767:
# Parameters: { "n_estimator", "num_leaves" } are not used.
#
# The Accuracy of the model is :  0.7685042315425258
# The confusion Matrix is
# array([[ 8197, 11148],
#        [ 3705, 41111]])

# %%
# Feature Importance Plot using XGBClassifier
plt.rcParams['figure.figsize'] = [12, 9]
plot_importance(model_xgb);

# %% [markdown]
# Model - III Bert Model

# %%
# !pip install transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting transformers
#   Downloading transformers-4.29.1-py3-none-any.whl (7.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.1/7.1 MB 53.0 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.12.0)
# Collecting huggingface-hub<1.0,>=0.14.1 (from transformers)
#   Downloading huggingface_hub-0.14.1-py3-none-any.whl (224 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.5/224.5 kB 24.2 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.22.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2022.10.31)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.27.1)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1 (from transformers)
#   Downloading tokenizers-0.13.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 102.4 MB/s eta 0:00:00
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.65.0)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.14.1->transformers) (2023.4.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.14.1->transformers) (4.5.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.4)
# Installing collected packages: tokenizers, huggingface-hub, transformers
# Successfully installed huggingface-hub-0.14.1 tokenizers-0.13.3 transformers-4.29.1

# %%
import torch
import pandas as pd
from sklearn.model_selection import train_test_split
from torch.utils.data import TensorDataset, DataLoader, RandomSampler, SequentialSampler
from transformers import BertTokenizer, BertForSequenceClassification, AdamW, get_linear_schedule_with_warmup
from sklearn.metrics import accuracy_score, f1_score

df_train = pd.read_csv("/content/drive/MyDrive/data/drugsComTrain_raw.csv")
df_test = pd.read_csv("/content/drive/MyDrive/data/drugsComTest_raw.csv")

# %%
sentiment_labels = {
    1: 0,
    2: 0,
    3: 1,
    4: 1,
    5: 2,
    6: 2,
    7: 3,
    8: 3,
    9: 4,
    10: 4
}

def preprocess_data(df):
    df['sentiment'] = df['rating'].apply(lambda x: sentiment_labels[x])
    df['text'] = df['condition'] + " " + df['review']
    return df

df_train = preprocess_data(df_train)
df_test = preprocess_data(df_test)

# %%
import transformers as ppb
tokenizer = ppb.BertTokenizer.from_pretrained('bert-base-uncased')
model = ppb.BertForSequenceClassification.from_pretrained('bert-base-uncased', num_labels=5)
# Out:
# Downloading (…)solve/main/vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading (…)okenizer_config.json:   0%|          | 0.00/28.0 [00:00<?, ?B/s]
# Downloading (…)lve/main/config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/440M [00:00<?, ?B/s]
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertForSequenceClassification: ['cls.seq_relationship.bias', 'cls.predictions.bias', 'cls.predictions.transform.dense.bias', 'cls.seq_relationship.weight', 'cls.predictions.decoder.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.LayerNorm.weight']
# - This IS expected if you are initializing BertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
import numpy as np
def prepare_dataset(df):
    df = df.dropna(subset=['text'])  # Drop rows with missing values in the 'text' column
    tokenized = df['text'].apply(lambda x: tokenizer.encode(x, add_special_tokens=True, max_length=64, truncation=True))
    max_len = 64
    padded = np.array([i + [0]*(max_len-len(i)) for i in tokenized.values])
    attention_masks = np.where(padded != 0, 1, 0)
    labels = torch.tensor(df['sentiment'].values)
    input_ids = torch.tensor(padded)
    attention_masks = torch.tensor(attention_masks)
    dataset = TensorDataset(input_ids, attention_masks, labels)
    return dataset

train_dataset = prepare_dataset(df_train)
test_dataset = prepare_dataset(df_test)

batch_size = 32
train_dataloader = DataLoader(train_dataset, sampler=RandomSampler(train_dataset), batch_size=batch_size)
test_dataloader = DataLoader(test_dataset, sampler=SequentialSampler(test_dataset), batch_size=batch_size)

# %%
optimizer = AdamW(model.parameters(), lr=2e-5)
total_steps = len(train_dataloader) * 5
scheduler = get_linear_schedule_with_warmup(optimizer, num_warmup_steps=0, num_training_steps=total_steps)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)
epochs_5 = 5
epochs_10 = 10
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/optimization.py:407: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(

# %%
from tqdm import tqdm
train_loss_values_5 = []
epoch_numbers_5 = []

for epoch in range(epochs_5):
    model.train()
    train_loss = 0
    progress_bar = tqdm(train_dataloader, desc=f"Epoch {epoch + 1}/{epochs_5}", unit="batch")
    for batch in train_dataloader:
        input_ids, attention_masks, labels = batch
        input_ids = input_ids.to(device)
        attention_masks = attention_masks.to(device)
        labels = labels.to(device)
        model.zero_grad()
        outputs = model(input_ids, attention_mask=attention_masks, labels=labels)
        loss = outputs[0]
        train_loss += loss.item()
        loss.backward()
        optimizer.step()
        scheduler.step()
        progress_bar.set_postfix({'Training Loss': '{:.3f}'.format(loss.item())})
    avg_train_loss = train_loss / len(train_dataloader)
    train_loss_values_5.append(avg_train_loss)
    epoch_numbers_5.append(epoch+1)
    print(f"Epoch {epoch + 1}/{epochs_5}, Training loss: {avg_train_loss}")
# Out:
# Epoch 1/5:   0%|          | 0/5013 [00:07<?, ?batch/s, Training Loss=0.760]
# Epoch 1/5:   0%|          | 0/5013 [09:29<?, ?batch/s, Training Loss=0.505]
# Epoch 1/5, Training loss: 0.4856050218885206
# Streaming output truncated to the last 5000 lines.
# Epoch 2/5:   0%|          | 0/5013 [00:01<?, ?batch/s, Training Loss=0.558]
# Epoch 2/5:   0%|          | 0/5013 [00:01<?, ?batch/s, Training Loss=0.557]
# Epoch 2/5:   0%|          | 0/5013 [00:02<?, ?batch/s, Training Loss=0.260]
# Epoch 2/5:   0%|          | 0/5013 [00:02<?, ?batch/s, Training Loss=0.381]
# Epoch 2/5:   0%|          | 0/5013 [00:02<?, ?batch/s, Training Loss=0.514]
# Epoch 2/5:   0%|          | 0/5013 [00:02<?, ?batch/s, Training Loss=0.443]
# Epoch 2/5:   0%|          | 0/5013 [00:02<?, ?batch/s, Training Loss=0.353]
# Epoch 2/5:   0%|          | 0/5013 [00:02<?, ?batch/s, Training Loss=0.542]
# Epoch 2/5:   0%|          | 0/5013 [00:02<?, ?batch/s, Training Loss=0.805]
# Epoch 2/5:   0%|          | 0/5013 [00:02<?, ?batch/s, Training Loss=0.379]
# Epoch 2/5:   0%|          | 0/5013 [00:02<?, ?batch/s, Training Loss=0.440]
# Epoch 2/5:   0%|          | 0/5013 [00:03<?, ?batch/s, Training Loss=0.422]
# Epoch 2/5:   0%|          | 0/5013 [00:03<?, ?batch/s, Training Loss=0.274]
# Epoch 2/5:   0%|          | 0/5013 [00:03<?, ?batch/s, Training Loss=0.528]
# Epoch 2/5:   0%|          | 0/5013 [00:03<?, ?batch/s, Training Loss=0.328]
# Epoch 2/5:   0%|          | 0/5013 [00:03<?, ?batch/s, Training Loss=0.343]
# Epoch 2/5:   0%|          | 0/5013 [00:03<?, ?batch/s, Training Loss=0.253]
# Epoch 2/5:   0%|          | 0/5013 [00:03<?, ?batch/s, Training Loss=0.486]
# Epoch 2/5:   0%|          | 0/5013 [00:03<?, ?batch/s, Training Loss=0.338]
# Epoch 2/5:   0%|          | 0/5013 [00:04<?, ?batch/s, Training Loss=0.402]
# Epoch 2/5:   0%|          | 0/5013 [00:04<?, ?batch/s, Training Loss=0.280]
# Epoch 2/5:   0%|          | 0/5013 [00:04<?, ?batch/s, Training Loss=0.258]
# Epoch 2/5:   0%|          | 0/5013 [00:04<?, ?batch/s, Training Loss=0.514]
# Epoch 2/5:   0%|          | 0/5013 [00:04<?, ?batch/s, Training Loss=0.539]
# Epoch 2/5:   0%|          | 0/5013 [00:04<?, ?batch/s, Training Loss=0.345]
# Epoch 2/5:   0%|          | 0/5013 [00:04<?, ?batch/s, Training Loss=0.337]
# Epoch 2/5:   0%|          | 0/5013 [00:04<?, ?batch/s, Training Loss=0.237]
# Epoch 2/5:   0%|          | 0/5013 [00:04<?, ?batch/s, Training Loss=0.239]
# Epoch 2/5:   0%|          | 0/5013 [00:05<?, ?batch/s, Training Loss=0.626]
# Epoch 2/5:   0%|          | 0/5013 [00:05<?, ?batch/s, Training Loss=0.427]
# Epoch 2/5:   0%|          | 0/5013 [00:05<?, ?batch/s, Training Loss=0.549]
# Epoch 2/5:   0%|          | 0/5013 [00:05<?, ?batch/s, Training Loss=0.270]
# Epoch 2/5:   0%|          | 0/5013 [00:05<?, ?batch/s, Training Loss=0.543]
# Epoch 2/5:   0%|          | 0/5013 [00:05<?, ?batch/s, Training Loss=0.367]
# Epoch 2/5:   0%|          | 0/5013 [00:05<?, ?batch/s, Training Loss=0.378]
# Epoch 2/5:   0%|          | 0/5013 [00:05<?, ?batch/s, Training Loss=0.297]
# Epoch 2/5:   0%|          | 0/5013 [00:05<?, ?batch/s, Training Loss=0.336]
# Epoch 2/5:   0%|          | 0/5013 [00:06<?, ?batch/s, Training Loss=0.322]
# Epoch 2/5:   0%|          | 0/5013 [00:06<?, ?batch/s, Training Loss=0.388]
# Epoch 2/5:   0%|          | 0/5013 [00:06<?, ?batch/s, Training Loss=0.436]
# Epoch 2/5:   0%|          | 0/5013 [00:06<?, ?batch/s, Training Loss=0.490]
# Epoch 2/5:   0%|          | 0/5013 [00:06<?, ?batch/s, Training Loss=0.326]
# Epoch 2/5:   0%|          | 0/5013 [00:06<?, ?batch/s, Training Loss=0.407]
# Epoch 2/5:   0%|          | 0/5013 [00:06<?, ?batch/s, Training Loss=0.277]
# Epoch 2/5:   0%|          | 0/5013 [00:06<?, ?batch/s, Training Loss=0.353]
# Epoch 2/5:   0%|          | 0/5013 [00:07<?, ?batch/s, Training Loss=0.357]
# Epoch 2/5:   0%|          | 0/5013 [00:07<?, ?batch/s, Training Loss=0.486]
# Epoch 2/5:   0%|          | 0/5013 [00:07<?, ?batch/s, Training Loss=0.455]
# Epoch 2/5:   0%|          | 0/5013 [00:07<?, ?batch/s, Training Loss=0.341]
# Epoch 2/5:   0%|          | 0/5013 [00:07<?, ?batch/s, Training Loss=0.416]
# Epoch 2/5:   0%|          | 0/5013 [00:07<?, ?batch/s, Training Loss=0.161]
# Epoch 2/5:   0%|          | 0/5013 [00:07<?, ?batch/s, Training Loss=0.437]
# Epoch 2/5:   0%|          | 0/5013 [00:07<?, ?batch/s, Training Loss=0.542]
# Epoch 2/5:   0%|          | 0/5013 [00:07<?, ?batch/s, Training Loss=0.433]
# Epoch 2/5:   0%|          | 0/5013 [00:08<?, ?batch/s, Training Loss=0.321]
# Epoch 2/5:   0%|          | 0/5013 [00:08<?, ?batch/s, Training Loss=0.526]
# Epoch 2/5:   0%|          | 0/5013 [00:08<?, ?batch/s, Training Loss=0.394]
# Epoch 2/5:   0%|          | 0/5013 [00:08<?, ?batch/s, Training Loss=0.529]
# Epoch 2/5:   0%|          | 0/5013 [00:08<?, ?batch/s, Training Loss=0.432]
# Epoch 2/5:   0%|          | 0/5013 [00:08<?, ?batch/s, Training Loss=0.414]
# Epoch 2/5:   0%|          | 0/5013 [00:08<?, ?batch/s, Training Loss=0.333]
# Epoch 2/5:   0%|          | 0/5013 [00:08<?, ?batch/s, Training Loss=0.395]
# Epoch 2/5:   0%|          | 0/5013 [00:09<?, ?batch/s, Training Loss=0.458]
# Epoch 2/5:   0%|          | 0/5013 [00:09<?, ?batch/s, Training Loss=0.227]
# Epoch 2/5:   0%|          | 0/5013 [00:09<?, ?batch/s, Training Loss=0.306]
# Epoch 2/5:   0%|          | 0/5013 [00:09<?, ?batch/s, Training Loss=0.322]
# Epoch 2/5:   0%|          | 0/5013 [00:09<?, ?batch/s, Training Loss=0.334]
# Epoch 2/5:   0%|          | 0/5013 [00:09<?, ?batch/s, Training Loss=0.234]
# Epoch 2/5:   0%|          | 0/5013 [00:09<?, ?batch/s, Training Loss=0.436]
# Epoch 2/5:   0%|          | 0/5013 [00:09<?, ?batch/s, Training Loss=0.418]
# Epoch 2/5:   0%|          | 0/5013 [00:09<?, ?batch/s, Training Loss=0.226]
# Epoch 2/5:   0%|          | 0/5013 [00:10<?, ?batch/s, Training Loss=0.436]
# Epoch 2/5:   0%|          | 0/5013 [00:10<?, ?batch/s, Training Loss=0.228]
# Epoch 2/5:   0%|          | 0/5013 [00:10<?, ?batch/s, Training Loss=0.254]
# Epoch 2/5:   0%|          | 0/5013 [00:10<?, ?batch/s, Training Loss=0.384]
# Epoch 2/5:   0%|          | 0/5013 [00:10<?, ?batch/s, Training Loss=0.582]
# Epoch 2/5:   0%|          | 0/5013 [00:10<?, ?batch/s, Training Loss=0.440]
# Epoch 2/5:   0%|          | 0/5013 [00:10<?, ?batch/s, Training Loss=0.470]
# Epoch 2/5:   0%|          | 0/5013 [00:10<?, ?batch/s, Training Loss=0.404]
# Epoch 2/5:   0%|          | 0/5013 [00:11<?, ?batch/s, Training Loss=0.317]
# Epoch 2/5:   0%|          | 0/5013 [00:11<?, ?batch/s, Training Loss=0.272]
# Epoch 2/5:   0%|          | 0/5013 [00:11<?, ?batch/s, Training Loss=0.462]
# Epoch 2/5:   0%|          | 0/5013 [00:11<?, ?batch/s, Training Loss=0.596]
# Epoch 2/5:   0%|          | 0/5013 [00:11<?, ?batch/s, Training Loss=0.602]
# Epoch 2/5:   0%|          | 0/5013 [00:11<?, ?batch/s, Training Loss=0.317]
# Epoch 2/5:   0%|          | 0/5013 [00:11<?, ?batch/s, Training Loss=0.570]
# Epoch 2/5:   0%|          | 0/5013 [00:11<?, ?batch/s, Training Loss=0.486]
# Epoch 2/5:   0%|          | 0/5013 [00:11<?, ?batch/s, Training Loss=0.239]
# Epoch 2/5:   0%|          | 0/5013 [00:12<?, ?batch/s, Training Loss=0.391]
# Epoch 2/5:   0%|          | 0/5013 [00:12<?, ?batch/s, Training Loss=0.593]
# Epoch 2/5:   0%|          | 0/5013 [00:12<?, ?batch/s, Training Loss=0.807]
# Epoch 2/5:   0%|          | 0/5013 [00:12<?, ?batch/s, Training Loss=0.343]
# Epoch 2/5:   0%|          | 0/5013 [00:12<?, ?batch/s, Training Loss=0.251]
# Epoch 2/5:   0%|          | 0/5013 [00:12<?, ?batch/s, Training Loss=0.477]
# Epoch 2/5:   0%|          | 0/5013 [00:12<?, ?batch/s, Training Loss=0.479]
# Epoch 2/5:   0%|          | 0/5013 [00:12<?, ?batch/s, Training Loss=0.582]
# Epoch 2/5:   0%|          | 0/5013 [00:13<?, ?batch/s, Training Loss=0.449]
# Epoch 2/5:   0%|          | 0/5013 [00:13<?, ?batch/s, Training Loss=0.393]
# Epoch 2/5:   0%|          | 0/5013 [00:13<?, ?batch/s, Training Loss=0.451]
# Epoch 2/5:   0%|          | 0/5013 [00:13<?, ?batch/s, Training Loss=0.317]
# Epoch 2/5:   0%|          | 0/5013 [00:13<?, ?batch/s, Training Loss=0.315]
# Epoch 2/5:   0%|          | 0/5013 [00:13<?, ?batch/s, Training Loss=0.307]
# Epoch 2/5:   0%|          | 0/5013 [00:13<?, ?batch/s, Training Loss=0.468]
# Epoch 2/5:   0%|          | 0/5013 [00:13<?, ?batch/s, Training Loss=0.441]
# Epoch 2/5:   0%|          | 0/5013 [00:13<?, ?batch/s, Training Loss=0.267]
# Epoch 2/5:   0%|          | 0/5013 [00:14<?, ?batch/s, Training Loss=0.279]
# Epoch 2/5:   0%|          | 0/5013 [00:14<?, ?batch/s, Training Loss=0.364]
# Epoch 2/5:   0%|          | 0/5013 [00:14<?, ?batch/s, Training Loss=0.488]
# Epoch 2/5:   0%|          | 0/5013 [00:14<?, ?batch/s, Training Loss=0.304]
# Epoch 2/5:   0%|          | 0/5013 [00:14<?, ?batch/s, Training Loss=0.484]
# Epoch 2/5:   0%|          | 0/5013 [00:14<?, ?batch/s, Training Loss=0.301]
# Epoch 2/5:   0%|          | 0/5013 [00:14<?, ?batch/s, Training Loss=0.344]
# Epoch 2/5:   0%|          | 0/5013 [00:14<?, ?batch/s, Training Loss=0.517]
# Epoch 2/5:   0%|          | 0/5013 [00:15<?, ?batch/s, Training Loss=0.455]
# Epoch 2/5:   0%|          | 0/5013 [00:15<?, ?batch/s, Training Loss=0.419]
# Epoch 2/5:   0%|          | 0/5013 [00:15<?, ?batch/s, Training Loss=0.284]
# Epoch 2/5:   0%|          | 0/5013 [00:15<?, ?batch/s, Training Loss=0.295]
# Epoch 2/5:   0%|          | 0/5013 [00:15<?, ?batch/s, Training Loss=0.327]
# Epoch 2/5:   0%|          | 0/5013 [00:15<?, ?batch/s, Training Loss=0.292]
# Epoch 2/5:   0%|          | 0/5013 [00:15<?, ?batch/s, Training Loss=0.380]
# Epoch 2/5:   0%|          | 0/5013 [00:15<?, ?batch/s, Training Loss=0.475]
# Epoch 2/5:   0%|          | 0/5013 [00:15<?, ?batch/s, Training Loss=0.559]
# Epoch 2/5:   0%|          | 0/5013 [00:16<?, ?batch/s, Training Loss=0.238]
# Epoch 2/5:   0%|          | 0/5013 [00:16<?, ?batch/s, Training Loss=0.472]
# Epoch 2/5:   0%|          | 0/5013 [00:16<?, ?batch/s, Training Loss=0.492]
# Epoch 2/5:   0%|          | 0/5013 [00:16<?, ?batch/s, Training Loss=0.187]
# Epoch 2/5:   0%|          | 0/5013 [00:16<?, ?batch/s, Training Loss=0.355]
# Epoch 2/5:   0%|          | 0/5013 [00:16<?, ?batch/s, Training Loss=0.485]
# Epoch 2/5:   0%|          | 0/5013 [00:16<?, ?batch/s, Training Loss=0.604]
# Epoch 2/5:   0%|          | 0/5013 [00:16<?, ?batch/s, Training Loss=0.266]
# Epoch 2/5:   0%|          | 0/5013 [00:17<?, ?batch/s, Training Loss=0.390]
# Epoch 2/5:   0%|          | 0/5013 [00:17<?, ?batch/s, Training Loss=0.593]
# Epoch 2/5:   0%|          | 0/5013 [00:17<?, ?batch/s, Training Loss=0.158]
# Epoch 2/5:   0%|          | 0/5013 [00:17<?, ?batch/s, Training Loss=0.247]
# Epoch 2/5:   0%|          | 0/5013 [00:17<?, ?batch/s, Training Loss=0.550]
# Epoch 2/5:   0%|          | 0/5013 [00:17<?, ?batch/s, Training Loss=0.248]
# Epoch 2/5:   0%|          | 0/5013 [00:17<?, ?batch/s, Training Loss=0.517]
# Epoch 2/5:   0%|          | 0/5013 [00:17<?, ?batch/s, Training Loss=0.243]
# Epoch 2/5:   0%|          | 0/5013 [00:17<?, ?batch/s, Training Loss=0.512]
# Epoch 2/5:   0%|          | 0/5013 [00:18<?, ?batch/s, Training Loss=0.435]
# Epoch 2/5:   0%|          | 0/5013 [00:18<?, ?batch/s, Training Loss=0.301]
# Epoch 2/5:   0%|          | 0/5013 [00:18<?, ?batch/s, Training Loss=0.573]
# Epoch 2/5:   0%|          | 0/5013 [00:18<?, ?batch/s, Training Loss=0.342]
# Epoch 2/5:   0%|          | 0/5013 [00:18<?, ?batch/s, Training Loss=0.759]
# Epoch 2/5:   0%|          | 0/5013 [00:18<?, ?batch/s, Training Loss=0.242]
# Epoch 2/5:   0%|          | 0/5013 [00:18<?, ?batch/s, Training Loss=0.319]
# Epoch 2/5:   0%|          | 0/5013 [00:18<?, ?batch/s, Training Loss=0.489]
# Epoch 2/5:   0%|          | 0/5013 [00:19<?, ?batch/s, Training Loss=0.136]
# Epoch 2/5:   0%|          | 0/5013 [00:19<?, ?batch/s, Training Loss=0.375]
# Epoch 2/5:   0%|          | 0/5013 [00:19<?, ?batch/s, Training Loss=0.365]
# Epoch 2/5:   0%|          | 0/5013 [00:19<?, ?batch/s, Training Loss=0.396]
# Epoch 2/5:   0%|          | 0/5013 [00:19<?, ?batch/s, Training Loss=0.680]
# Epoch 2/5:   0%|          | 0/5013 [00:19<?, ?batch/s, Training Loss=0.454]
# Epoch 2/5:   0%|          | 0/5013 [00:19<?, ?batch/s, Training Loss=0.284]
# Epoch 2/5:   0%|          | 0/5013 [00:19<?, ?batch/s, Training Loss=0.325]
# Epoch 2/5:   0%|          | 0/5013 [00:19<?, ?batch/s, Training Loss=0.418]
# Epoch 2/5:   0%|          | 0/5013 [00:20<?, ?batch/s, Training Loss=0.445]
# Epoch 2/5:   0%|          | 0/5013 [00:20<?, ?batch/s, Training Loss=0.441]
# Epoch 2/5:   0%|          | 0/5013 [00:20<?, ?batch/s, Training Loss=0.439]
# Epoch 2/5:   0%|          | 0/5013 [00:20<?, ?batch/s, Training Loss=0.324]
# Epoch 2/5:   0%|          | 0/5013 [00:20<?, ?batch/s, Training Loss=0.253]
# Epoch 2/5:   0%|          | 0/5013 [00:20<?, ?batch/s, Training Loss=0.513]
# Epoch 2/5:   0%|          | 0/5013 [00:20<?, ?batch/s, Training Loss=0.306]
# Epoch 2/5:   0%|          | 0/5013 [00:20<?, ?batch/s, Training Loss=0.299]
# Epoch 2/5:   0%|          | 0/5013 [00:21<?, ?batch/s, Training Loss=0.307]
# Epoch 2/5:   0%|          | 0/5013 [00:21<?, ?batch/s, Training Loss=0.613]
# Epoch 2/5:   0%|          | 0/5013 [00:21<?, ?batch/s, Training Loss=0.247]
# Epoch 2/5:   0%|          | 0/5013 [00:21<?, ?batch/s, Training Loss=0.338]
# Epoch 2/5:   0%|          | 0/5013 [00:21<?, ?batch/s, Training Loss=0.705]
# Epoch 2/5:   0%|          | 0/5013 [00:21<?, ?batch/s, Training Loss=0.346]
# Epoch 2/5:   0%|          | 0/5013 [00:21<?, ?batch/s, Training Loss=0.558]
# Epoch 2/5:   0%|          | 0/5013 [00:21<?, ?batch/s, Training Loss=0.256]
# Epoch 2/5:   0%|          | 0/5013 [00:21<?, ?batch/s, Training Loss=0.303]
# Epoch 2/5:   0%|          | 0/5013 [00:22<?, ?batch/s, Training Loss=0.328]
# Epoch 2/5:   0%|          | 0/5013 [00:22<?, ?batch/s, Training Loss=0.328]
# Epoch 2/5:   0%|          | 0/5013 [00:22<?, ?batch/s, Training Loss=0.299]
# Epoch 2/5:   0%|          | 0/5013 [00:22<?, ?batch/s, Training Loss=0.327]
# Epoch 2/5:   0%|          | 0/5013 [00:22<?, ?batch/s, Training Loss=0.368]
# Epoch 2/5:   0%|          | 0/5013 [00:22<?, ?batch/s, Training Loss=0.719]
# Epoch 2/5:   0%|          | 0/5013 [00:22<?, ?batch/s, Training Loss=0.535]
# Epoch 2/5:   0%|          | 0/5013 [00:22<?, ?batch/s, Training Loss=0.332]
# Epoch 2/5:   0%|          | 0/5013 [00:23<?, ?batch/s, Training Loss=0.556]
# Epoch 2/5:   0%|          | 0/5013 [00:23<?, ?batch/s, Training Loss=0.502]
# Epoch 2/5:   0%|          | 0/5013 [00:23<?, ?batch/s, Training Loss=0.631]
# Epoch 2/5:   0%|          | 0/5013 [00:23<?, ?batch/s, Training Loss=0.306]
# Epoch 2/5:   0%|          | 0/5013 [00:23<?, ?batch/s, Training Loss=0.461]
# Epoch 2/5:   0%|          | 0/5013 [00:23<?, ?batch/s, Training Loss=0.264]
# Epoch 2/5:   0%|          | 0/5013 [00:23<?, ?batch/s, Training Loss=0.405]
# Epoch 2/5:   0%|          | 0/5013 [00:23<?, ?batch/s, Training Loss=0.246]
# Epoch 2/5:   0%|          | 0/5013 [00:23<?, ?batch/s, Training Loss=0.561]
# Epoch 2/5:   0%|          | 0/5013 [00:24<?, ?batch/s, Training Loss=0.250]
# Epoch 2/5:   0%|          | 0/5013 [00:24<?, ?batch/s, Training Loss=0.513]
# Epoch 2/5:   0%|          | 0/5013 [00:24<?, ?batch/s, Training Loss=0.446]
# Epoch 2/5:   0%|          | 0/5013 [00:24<?, ?batch/s, Training Loss=0.309]
# Epoch 2/5:   0%|          | 0/5013 [00:24<?, ?batch/s, Training Loss=0.198]
# Epoch 2/5:   0%|          | 0/5013 [00:24<?, ?batch/s, Training Loss=0.385]
# Epoch 2/5:   0%|          | 0/5013 [00:24<?, ?batch/s, Training Loss=0.190]
# Epoch 2/5:   0%|          | 0/5013 [00:24<?, ?batch/s, Training Loss=0.322]
# Epoch 2/5:   0%|          | 0/5013 [00:25<?, ?batch/s, Training Loss=0.342]
# Epoch 2/5:   0%|          | 0/5013 [00:25<?, ?batch/s, Training Loss=0.190]
# Epoch 2/5:   0%|          | 0/5013 [00:25<?, ?batch/s, Training Loss=0.434]
# Epoch 2/5:   0%|          | 0/5013 [00:25<?, ?batch/s, Training Loss=0.507]
# Epoch 2/5:   0%|          | 0/5013 [00:25<?, ?batch/s, Training Loss=0.327]
# Epoch 2/5:   0%|          | 0/5013 [00:25<?, ?batch/s, Training Loss=0.532]
# Epoch 2/5:   0%|          | 0/5013 [00:25<?, ?batch/s, Training Loss=0.497]
# Epoch 2/5:   0%|          | 0/5013 [00:25<?, ?batch/s, Training Loss=0.577]
# Epoch 2/5:   0%|          | 0/5013 [00:25<?, ?batch/s, Training Loss=0.562]
# Epoch 2/5:   0%|          | 0/5013 [00:26<?, ?batch/s, Training Loss=0.641]
# Epoch 2/5:   0%|          | 0/5013 [00:26<?, ?batch/s, Training Loss=0.423]
# Epoch 2/5:   0%|          | 0/5013 [00:26<?, ?batch/s, Training Loss=0.300]
# Epoch 2/5:   0%|          | 0/5013 [00:26<?, ?batch/s, Training Loss=0.376]
# Epoch 2/5:   0%|          | 0/5013 [00:26<?, ?batch/s, Training Loss=0.334]
# Epoch 2/5:   0%|          | 0/5013 [00:26<?, ?batch/s, Training Loss=0.247]
# Epoch 2/5:   0%|          | 0/5013 [00:26<?, ?batch/s, Training Loss=0.248]
# Epoch 2/5:   0%|          | 0/5013 [00:26<?, ?batch/s, Training Loss=0.344]
# Epoch 2/5:   0%|          | 0/5013 [00:27<?, ?batch/s, Training Loss=0.324]
# Epoch 2/5:   0%|          | 0/5013 [00:27<?, ?batch/s, Training Loss=0.348]
# Epoch 2/5:   0%|          | 0/5013 [00:27<?, ?batch/s, Training Loss=0.578]
# Epoch 2/5:   0%|          | 0/5013 [00:27<?, ?batch/s, Training Loss=0.401]
# Epoch 2/5:   0%|          | 0/5013 [00:27<?, ?batch/s, Training Loss=0.358]
# Epoch 2/5:   0%|          | 0/5013 [00:27<?, ?batch/s, Training Loss=0.360]
# Epoch 2/5:   0%|          | 0/5013 [00:27<?, ?batch/s, Training Loss=0.461]
# Epoch 2/5:   0%|          | 0/5013 [00:27<?, ?batch/s, Training Loss=0.516]
# Epoch 2/5:   0%|          | 0/5013 [00:27<?, ?batch/s, Training Loss=0.438]
# Epoch 2/5:   0%|          | 0/5013 [00:28<?, ?batch/s, Training Loss=0.240]
# Epoch 2/5:   0%|          | 0/5013 [00:28<?, ?batch/s, Training Loss=0.622]
# Epoch 2/5:   0%|          | 0/5013 [00:28<?, ?batch/s, Training Loss=0.408]
# Epoch 2/5:   0%|          | 0/5013 [00:28<?, ?batch/s, Training Loss=0.557]
# Epoch 2/5:   0%|          | 0/5013 [00:28<?, ?batch/s, Training Loss=0.464]
# Epoch 2/5:   0%|          | 0/5013 [00:28<?, ?batch/s, Training Loss=0.341]
# Epoch 2/5:   0%|          | 0/5013 [00:28<?, ?batch/s, Training Loss=0.318]
# Epoch 2/5:   0%|          | 0/5013 [00:28<?, ?batch/s, Training Loss=0.241]
# Epoch 2/5:   0%|          | 0/5013 [00:29<?, ?batch/s, Training Loss=0.333]
# Epoch 2/5:   0%|          | 0/5013 [00:29<?, ?batch/s, Training Loss=0.496]
# Epoch 2/5:   0%|          | 0/5013 [00:29<?, ?batch/s, Training Loss=0.570]
# Epoch 2/5:   0%|          | 0/5013 [00:29<?, ?batch/s, Training Loss=0.505]
# Epoch 2/5:   0%|          | 0/5013 [00:29<?, ?batch/s, Training Loss=0.508]
# Epoch 2/5:   0%|          | 0/5013 [00:29<?, ?batch/s, Training Loss=0.391]
# Epoch 2/5:   0%|          | 0/5013 [00:29<?, ?batch/s, Training Loss=0.441]
# Epoch 2/5:   0%|          | 0/5013 [00:29<?, ?batch/s, Training Loss=0.325]
# Epoch 2/5:   0%|          | 0/5013 [00:29<?, ?batch/s, Training Loss=0.346]
# Epoch 2/5:   0%|          | 0/5013 [00:30<?, ?batch/s, Training Loss=0.583]
# Epoch 2/5:   0%|          | 0/5013 [00:30<?, ?batch/s, Training Loss=0.228]
# Epoch 2/5:   0%|          | 0/5013 [00:30<?, ?batch/s, Training Loss=0.345]
# Epoch 2/5:   0%|          | 0/5013 [00:30<?, ?batch/s, Training Loss=0.302]
# Epoch 2/5:   0%|          | 0/5013 [00:30<?, ?batch/s, Training Loss=0.320]
# Epoch 2/5:   0%|          | 0/5013 [00:30<?, ?batch/s, Training Loss=0.491]
# Epoch 2/5:   0%|          | 0/5013 [00:30<?, ?batch/s, Training Loss=0.535]
# Epoch 2/5:   0%|          | 0/5013 [00:30<?, ?batch/s, Training Loss=0.203]
# Epoch 2/5:   0%|          | 0/5013 [00:31<?, ?batch/s, Training Loss=0.481]
# Epoch 2/5:   0%|          | 0/5013 [00:31<?, ?batch/s, Training Loss=0.467]
# Epoch 2/5:   0%|          | 0/5013 [00:31<?, ?batch/s, Training Loss=0.203]
# Epoch 2/5:   0%|          | 0/5013 [00:31<?, ?batch/s, Training Loss=0.266]
# Epoch 2/5:   0%|          | 0/5013 [00:31<?, ?batch/s, Training Loss=0.491]
# Epoch 2/5:   0%|          | 0/5013 [00:31<?, ?batch/s, Training Loss=0.519]
# Epoch 2/5:   0%|          | 0/5013 [00:31<?, ?batch/s, Training Loss=0.365]
# Epoch 2/5:   0%|          | 0/5013 [00:31<?, ?batch/s, Training Loss=0.277]
# Epoch 2/5:   0%|          | 0/5013 [00:31<?, ?batch/s, Training Loss=0.406]
# Epoch 2/5:   0%|          | 0/5013 [00:32<?, ?batch/s, Training Loss=0.477]
# Epoch 2/5:   0%|          | 0/5013 [00:32<?, ?batch/s, Training Loss=0.421]
# Epoch 2/5:   0%|          | 0/5013 [00:32<?, ?batch/s, Training Loss=0.311]
# Epoch 2/5:   0%|          | 0/5013 [00:32<?, ?batch/s, Training Loss=0.413]
# Epoch 2/5:   0%|          | 0/5013 [00:32<?, ?batch/s, Training Loss=0.395]
# Epoch 2/5:   0%|          | 0/5013 [00:32<?, ?batch/s, Training Loss=0.459]
# Epoch 2/5:   0%|          | 0/5013 [00:32<?, ?batch/s, Training Loss=0.264]
# Epoch 2/5:   0%|          | 0/5013 [00:32<?, ?batch/s, Training Loss=0.280]
# Epoch 2/5:   0%|          | 0/5013 [00:33<?, ?batch/s, Training Loss=0.359]
# Epoch 2/5:   0%|          | 0/5013 [00:33<?, ?batch/s, Training Loss=0.332]
# Epoch 2/5:   0%|          | 0/5013 [00:33<?, ?batch/s, Training Loss=0.281]
# Epoch 2/5:   0%|          | 0/5013 [00:33<?, ?batch/s, Training Loss=0.284]
# Epoch 2/5:   0%|          | 0/5013 [00:33<?, ?batch/s, Training Loss=0.385]
# Epoch 2/5:   0%|          | 0/5013 [00:33<?, ?batch/s, Training Loss=0.492]
# Epoch 2/5:   0%|          | 0/5013 [00:33<?, ?batch/s, Training Loss=0.437]
# Epoch 2/5:   0%|          | 0/5013 [00:33<?, ?batch/s, Training Loss=0.273]
# Epoch 2/5:   0%|          | 0/5013 [00:33<?, ?batch/s, Training Loss=0.392]
# Epoch 2/5:   0%|          | 0/5013 [00:34<?, ?batch/s, Training Loss=0.562]
# Epoch 2/5:   0%|          | 0/5013 [00:34<?, ?batch/s, Training Loss=0.656]
# Epoch 2/5:   0%|          | 0/5013 [00:34<?, ?batch/s, Training Loss=0.328]
# Epoch 2/5:   0%|          | 0/5013 [00:34<?, ?batch/s, Training Loss=0.327]
# Epoch 2/5:   0%|          | 0/5013 [00:34<?, ?batch/s, Training Loss=0.382]
# Epoch 2/5:   0%|          | 0/5013 [00:34<?, ?batch/s, Training Loss=0.511]
# Epoch 2/5:   0%|          | 0/5013 [00:34<?, ?batch/s, Training Loss=0.330]
# Epoch 2/5:   0%|          | 0/5013 [00:34<?, ?batch/s, Training Loss=0.355]
# Epoch 2/5:   0%|          | 0/5013 [00:35<?, ?batch/s, Training Loss=0.347]
# Epoch 2/5:   0%|          | 0/5013 [00:35<?, ?batch/s, Training Loss=0.248]
# Epoch 2/5:   0%|          | 0/5013 [00:35<?, ?batch/s, Training Loss=0.391]
# Epoch 2/5:   0%|          | 0/5013 [00:35<?, ?batch/s, Training Loss=0.349]
# Epoch 2/5:   0%|          | 0/5013 [00:35<?, ?batch/s, Training Loss=0.291]
# Epoch 2/5:   0%|          | 0/5013 [00:35<?, ?batch/s, Training Loss=0.406]
# Epoch 2/5:   0%|          | 0/5013 [00:35<?, ?batch/s, Training Loss=0.345]
# Epoch 2/5:   0%|          | 0/5013 [00:35<?, ?batch/s, Training Loss=0.286]
# Epoch 2/5:   0%|          | 0/5013 [00:35<?, ?batch/s, Training Loss=0.384]
# Epoch 2/5:   0%|          | 0/5013 [00:36<?, ?batch/s, Training Loss=0.426]
# Epoch 2/5:   0%|          | 0/5013 [00:36<?, ?batch/s, Training Loss=0.187]
# Epoch 2/5:   0%|          | 0/5013 [00:36<?, ?batch/s, Training Loss=0.221]
# Epoch 2/5:   0%|          | 0/5013 [00:36<?, ?batch/s, Training Loss=0.171]
# Epoch 2/5:   0%|          | 0/5013 [00:36<?, ?batch/s, Training Loss=0.255]
# Epoch 2/5:   0%|          | 0/5013 [00:36<?, ?batch/s, Training Loss=0.383]
# Epoch 2/5:   0%|          | 0/5013 [00:36<?, ?batch/s, Training Loss=0.392]
# Epoch 2/5:   0%|          | 0/5013 [00:36<?, ?batch/s, Training Loss=0.474]
# Epoch 2/5:   0%|          | 0/5013 [00:37<?, ?batch/s, Training Loss=0.301]
# Epoch 2/5:   0%|          | 0/5013 [00:37<?, ?batch/s, Training Loss=0.358]
# Epoch 2/5:   0%|          | 0/5013 [00:37<?, ?batch/s, Training Loss=0.291]
# Epoch 2/5:   0%|          | 0/5013 [00:37<?, ?batch/s, Training Loss=0.306]
# Epoch 2/5:   0%|          | 0/5013 [00:37<?, ?batch/s, Training Loss=0.308]
# Epoch 2/5:   0%|          | 0/5013 [00:37<?, ?batch/s, Training Loss=0.398]
# Epoch 2/5:   0%|          | 0/5013 [00:37<?, ?batch/s, Training Loss=0.158]
# Epoch 2/5:   0%|          | 0/5013 [00:37<?, ?batch/s, Training Loss=0.231]
# Epoch 2/5:   0%|          | 0/5013 [00:37<?, ?batch/s, Training Loss=0.254]
# Epoch 2/5:   0%|          | 0/5013 [00:38<?, ?batch/s, Training Loss=0.573]
# Epoch 2/5:   0%|          | 0/5013 [00:38<?, ?batch/s, Training Loss=0.354]
# Epoch 2/5:   0%|          | 0/5013 [00:38<?, ?batch/s, Training Loss=0.454]
# Epoch 2/5:   0%|          | 0/5013 [00:38<?, ?batch/s, Training Loss=0.358]
# Epoch 2/5:   0%|          | 0/5013 [00:38<?, ?batch/s, Training Loss=0.299]
# Epoch 2/5:   0%|          | 0/5013 [00:38<?, ?batch/s, Training Loss=0.548]
# Epoch 2/5:   0%|          | 0/5013 [00:38<?, ?batch/s, Training Loss=0.355]
# Epoch 2/5:   0%|          | 0/5013 [00:38<?, ?batch/s, Training Loss=0.347]
# Epoch 2/5:   0%|          | 0/5013 [00:39<?, ?batch/s, Training Loss=0.216]
# Epoch 2/5:   0%|          | 0/5013 [00:39<?, ?batch/s, Training Loss=0.349]
# Epoch 2/5:   0%|          | 0/5013 [00:39<?, ?batch/s, Training Loss=0.320]
# Epoch 2/5:   0%|          | 0/5013 [00:39<?, ?batch/s, Training Loss=0.445]
# Epoch 2/5:   0%|          | 0/5013 [00:39<?, ?batch/s, Training Loss=0.421]
# Epoch 2/5:   0%|          | 0/5013 [00:39<?, ?batch/s, Training Loss=0.331]
# Epoch 2/5:   0%|          | 0/5013 [00:39<?, ?batch/s, Training Loss=0.290]
# Epoch 2/5:   0%|          | 0/5013 [00:39<?, ?batch/s, Training Loss=0.390]
# Epoch 2/5:   0%|          | 0/5013 [00:39<?, ?batch/s, Training Loss=0.412]
# Epoch 2/5:   0%|          | 0/5013 [00:40<?, ?batch/s, Training Loss=0.403]
# Epoch 2/5:   0%|          | 0/5013 [00:40<?, ?batch/s, Training Loss=0.480]
# Epoch 2/5:   0%|          | 0/5013 [00:40<?, ?batch/s, Training Loss=0.441]
# Epoch 2/5:   0%|          | 0/5013 [00:40<?, ?batch/s, Training Loss=0.466]
# Epoch 2/5:   0%|          | 0/5013 [00:40<?, ?batch/s, Training Loss=0.610]
# Epoch 2/5:   0%|          | 0/5013 [00:40<?, ?batch/s, Training Loss=0.467]
# Epoch 2/5:   0%|          | 0/5013 [00:40<?, ?batch/s, Training Loss=0.303]
# Epoch 2/5:   0%|          | 0/5013 [00:40<?, ?batch/s, Training Loss=0.279]
# Epoch 2/5:   0%|          | 0/5013 [00:41<?, ?batch/s, Training Loss=0.300]
# Epoch 2/5:   0%|          | 0/5013 [00:41<?, ?batch/s, Training Loss=0.402]
# Epoch 2/5:   0%|          | 0/5013 [00:41<?, ?batch/s, Training Loss=0.438]
# Epoch 2/5:   0%|          | 0/5013 [00:41<?, ?batch/s, Training Loss=0.311]
# Epoch 2/5:   0%|          | 0/5013 [00:41<?, ?batch/s, Training Loss=0.499]
# Epoch 2/5:   0%|          | 0/5013 [00:41<?, ?batch/s, Training Loss=0.433]
# Epoch 2/5:   0%|          | 0/5013 [00:41<?, ?batch/s, Training Loss=0.527]
# Epoch 2/5:   0%|          | 0/5013 [00:41<?, ?batch/s, Training Loss=0.466]
# Epoch 2/5:   0%|          | 0/5013 [00:41<?, ?batch/s, Training Loss=0.322]
# Epoch 2/5:   0%|          | 0/5013 [00:42<?, ?batch/s, Training Loss=0.634]
# Epoch 2/5:   0%|          | 0/5013 [00:42<?, ?batch/s, Training Loss=0.419]
# Epoch 2/5:   0%|          | 0/5013 [00:42<?, ?batch/s, Training Loss=0.589]
# Epoch 2/5:   0%|          | 0/5013 [00:42<?, ?batch/s, Training Loss=0.340]
# Epoch 2/5:   0%|          | 0/5013 [00:42<?, ?batch/s, Training Loss=0.263]
# Epoch 2/5:   0%|          | 0/5013 [00:42<?, ?batch/s, Training Loss=0.290]
# Epoch 2/5:   0%|          | 0/5013 [00:42<?, ?batch/s, Training Loss=0.644]
# Epoch 2/5:   0%|          | 0/5013 [00:42<?, ?batch/s, Training Loss=0.491]
# Epoch 2/5:   0%|          | 0/5013 [00:43<?, ?batch/s, Training Loss=0.521]
# Epoch 2/5:   0%|          | 0/5013 [00:43<?, ?batch/s, Training Loss=0.276]
# Epoch 2/5:   0%|          | 0/5013 [00:43<?, ?batch/s, Training Loss=0.713]
# Epoch 2/5:   0%|          | 0/5013 [00:43<?, ?batch/s, Training Loss=0.399]
# Epoch 2/5:   0%|          | 0/5013 [00:43<?, ?batch/s, Training Loss=0.403]
# Epoch 2/5:   0%|          | 0/5013 [00:43<?, ?batch/s, Training Loss=0.250]
# Epoch 2/5:   0%|          | 0/5013 [00:43<?, ?batch/s, Training Loss=0.234]
# Epoch 2/5:   0%|          | 0/5013 [00:43<?, ?batch/s, Training Loss=0.834]
# Epoch 2/5:   0%|          | 0/5013 [00:43<?, ?batch/s, Training Loss=0.550]
# Epoch 2/5:   0%|          | 0/5013 [00:44<?, ?batch/s, Training Loss=0.252]
# Epoch 2/5:   0%|          | 0/5013 [00:44<?, ?batch/s, Training Loss=0.379]
# Epoch 2/5:   0%|          | 0/5013 [00:44<?, ?batch/s, Training Loss=0.371]
# Epoch 2/5:   0%|          | 0/5013 [00:44<?, ?batch/s, Training Loss=0.190]
# Epoch 2/5:   0%|          | 0/5013 [00:44<?, ?batch/s, Training Loss=0.405]
# Epoch 2/5:   0%|          | 0/5013 [00:44<?, ?batch/s, Training Loss=0.590]
# Epoch 2/5:   0%|          | 0/5013 [00:44<?, ?batch/s, Training Loss=0.343]
# Epoch 2/5:   0%|          | 0/5013 [00:44<?, ?batch/s, Training Loss=0.332]
# Epoch 2/5:   0%|          | 0/5013 [00:45<?, ?batch/s, Training Loss=0.331]
# Epoch 2/5:   0%|          | 0/5013 [00:45<?, ?batch/s, Training Loss=0.543]
# Epoch 2/5:   0%|          | 0/5013 [00:45<?, ?batch/s, Training Loss=0.401]
# Epoch 2/5:   0%|          | 0/5013 [00:45<?, ?batch/s, Training Loss=0.214]
# Epoch 2/5:   0%|          | 0/5013 [00:45<?, ?batch/s, Training Loss=0.668]
# Epoch 2/5:   0%|          | 0/5013 [00:45<?, ?batch/s, Training Loss=0.443]
# Epoch 2/5:   0%|          | 0/5013 [00:45<?, ?batch/s, Training Loss=0.470]
# Epoch 2/5:   0%|          | 0/5013 [00:45<?, ?batch/s, Training Loss=0.272]
# Epoch 2/5:   0%|          | 0/5013 [00:45<?, ?batch/s, Training Loss=0.523]
# Epoch 2/5:   0%|          | 0/5013 [00:46<?, ?batch/s, Training Loss=0.420]
# Epoch 2/5:   0%|          | 0/5013 [00:46<?, ?batch/s, Training Loss=0.719]
# Epoch 2/5:   0%|          | 0/5013 [00:46<?, ?batch/s, Training Loss=0.240]
# Epoch 2/5:   0%|          | 0/5013 [00:46<?, ?batch/s, Training Loss=0.363]
# Epoch 2/5:   0%|          | 0/5013 [00:46<?, ?batch/s, Training Loss=0.369]
# Epoch 2/5:   0%|          | 0/5013 [00:46<?, ?batch/s, Training Loss=0.285]
# Epoch 2/5:   0%|          | 0/5013 [00:46<?, ?batch/s, Training Loss=0.445]
# Epoch 2/5:   0%|          | 0/5013 [00:46<?, ?batch/s, Training Loss=0.334]
# Epoch 2/5:   0%|          | 0/5013 [00:47<?, ?batch/s, Training Loss=0.269]
# Epoch 2/5:   0%|          | 0/5013 [00:47<?, ?batch/s, Training Loss=0.271]
# Epoch 2/5:   0%|          | 0/5013 [00:47<?, ?batch/s, Training Loss=0.308]
# Epoch 2/5:   0%|          | 0/5013 [00:47<?, ?batch/s, Training Loss=0.349]
# Epoch 2/5:   0%|          | 0/5013 [00:47<?, ?batch/s, Training Loss=0.315]
# Epoch 2/5:   0%|          | 0/5013 [00:47<?, ?batch/s, Training Loss=0.350]
# Epoch 2/5:   0%|          | 0/5013 [00:47<?, ?batch/s, Training Loss=0.557]
# Epoch 2/5:   0%|          | 0/5013 [00:47<?, ?batch/s, Training Loss=0.346]
# Epoch 2/5:   0%|          | 0/5013 [00:47<?, ?batch/s, Training Loss=0.473]
# Epoch 2/5:   0%|          | 0/5013 [00:48<?, ?batch/s, Training Loss=0.530]
# Epoch 2/5:   0%|          | 0/5013 [00:48<?, ?batch/s, Training Loss=0.392]
# Epoch 2/5:   0%|          | 0/5013 [00:48<?, ?batch/s, Training Loss=0.267]
# Epoch 2/5:   0%|          | 0/5013 [00:48<?, ?batch/s, Training Loss=0.471]
# Epoch 2/5:   0%|          | 0/5013 [00:48<?, ?batch/s, Training Loss=0.539]
# Epoch 2/5:   0%|          | 0/5013 [00:48<?, ?batch/s, Training Loss=0.466]
# Epoch 2/5:   0%|          | 0/5013 [00:48<?, ?batch/s, Training Loss=0.473]
# Epoch 2/5:   0%|          | 0/5013 [00:48<?, ?batch/s, Training Loss=0.402]
# Epoch 2/5:   0%|          | 0/5013 [00:49<?, ?batch/s, Training Loss=0.300]
# Epoch 2/5:   0%|          | 0/5013 [00:49<?, ?batch/s, Training Loss=0.121]
# Epoch 2/5:   0%|          | 0/5013 [00:49<?, ?batch/s, Training Loss=0.548]
# Epoch 2/5:   0%|          | 0/5013 [00:49<?, ?batch/s, Training Loss=0.372]
# Epoch 2/5:   0%|          | 0/5013 [00:49<?, ?batch/s, Training Loss=0.252]
# Epoch 2/5:   0%|          | 0/5013 [00:49<?, ?batch/s, Training Loss=0.395]
# Epoch 2/5:   0%|          | 0/5013 [00:49<?, ?batch/s, Training Loss=0.327]
# Epoch 2/5:   0%|          | 0/5013 [00:49<?, ?batch/s, Training Loss=0.394]
# Epoch 2/5:   0%|          | 0/5013 [00:49<?, ?batch/s, Training Loss=0.342]
# Epoch 2/5:   0%|          | 0/5013 [00:50<?, ?batch/s, Training Loss=0.286]
# Epoch 2/5:   0%|          | 0/5013 [00:50<?, ?batch/s, Training Loss=0.124]
# Epoch 2/5:   0%|          | 0/5013 [00:50<?, ?batch/s, Training Loss=0.554]
# Epoch 2/5:   0%|          | 0/5013 [00:50<?, ?batch/s, Training Loss=0.540]
# Epoch 2/5:   0%|          | 0/5013 [00:50<?, ?batch/s, Training Loss=0.507]
# Epoch 2/5:   0%|          | 0/5013 [00:50<?, ?batch/s, Training Loss=0.421]
# Epoch 2/5:   0%|          | 0/5013 [00:50<?, ?batch/s, Training Loss=0.495]
# Epoch 2/5:   0%|          | 0/5013 [00:50<?, ?batch/s, Training Loss=0.316]
# Epoch 2/5:   0%|          | 0/5013 [00:51<?, ?batch/s, Training Loss=0.555]
# Epoch 2/5:   0%|          | 0/5013 [00:51<?, ?batch/s, Training Loss=0.492]
# Epoch 2/5:   0%|          | 0/5013 [00:51<?, ?batch/s, Training Loss=0.388]
# Epoch 2/5:   0%|          | 0/5013 [00:51<?, ?batch/s, Training Loss=0.297]
# Epoch 2/5:   0%|          | 0/5013 [00:51<?, ?batch/s, Training Loss=0.528]
# Epoch 2/5:   0%|          | 0/5013 [00:51<?, ?batch/s, Training Loss=0.504]
# Epoch 2/5:   0%|          | 0/5013 [00:51<?, ?batch/s, Training Loss=0.179]
# Epoch 2/5:   0%|          | 0/5013 [00:51<?, ?batch/s, Training Loss=0.254]
# Epoch 2/5:   0%|          | 0/5013 [00:51<?, ?batch/s, Training Loss=0.402]
# Epoch 2/5:   0%|          | 0/5013 [00:52<?, ?batch/s, Training Loss=0.218]
# Epoch 2/5:   0%|          | 0/5013 [00:52<?, ?batch/s, Training Loss=0.274]
# Epoch 2/5:   0%|          | 0/5013 [00:52<?, ?batch/s, Training Loss=0.655]
# Epoch 2/5:   0%|          | 0/5013 [00:52<?, ?batch/s, Training Loss=0.526]
# Epoch 2/5:   0%|          | 0/5013 [00:52<?, ?batch/s, Training Loss=0.635]
# Epoch 2/5:   0%|          | 0/5013 [00:52<?, ?batch/s, Training Loss=0.302]
# Epoch 2/5:   0%|          | 0/5013 [00:52<?, ?batch/s, Training Loss=0.301]
# Epoch 2/5:   0%|          | 0/5013 [00:52<?, ?batch/s, Training Loss=0.638]
# Epoch 2/5:   0%|          | 0/5013 [00:53<?, ?batch/s, Training Loss=0.293]
# Epoch 2/5:   0%|          | 0/5013 [00:53<?, ?batch/s, Training Loss=0.374]
# Epoch 2/5:   0%|          | 0/5013 [00:53<?, ?batch/s, Training Loss=0.191]
# Epoch 2/5:   0%|          | 0/5013 [00:53<?, ?batch/s, Training Loss=0.366]
# Epoch 2/5:   0%|          | 0/5013 [00:53<?, ?batch/s, Training Loss=0.497]
# Epoch 2/5:   0%|          | 0/5013 [00:53<?, ?batch/s, Training Loss=0.300]
# Epoch 2/5:   0%|          | 0/5013 [00:53<?, ?batch/s, Training Loss=0.280]
# Epoch 2/5:   0%|          | 0/5013 [00:53<?, ?batch/s, Training Loss=0.206]
# Epoch 2/5:   0%|          | 0/5013 [00:54<?, ?batch/s, Training Loss=0.354]
# Epoch 2/5:   0%|          | 0/5013 [00:54<?, ?batch/s, Training Loss=0.134]
# Epoch 2/5:   0%|          | 0/5013 [00:54<?, ?batch/s, Training Loss=0.234]
# Epoch 2/5:   0%|          | 0/5013 [00:54<?, ?batch/s, Training Loss=0.607]
# Epoch 2/5:   0%|          | 0/5013 [00:54<?, ?batch/s, Training Loss=0.369]
# Epoch 2/5:   0%|          | 0/5013 [00:54<?, ?batch/s, Training Loss=0.384]
# Epoch 2/5:   0%|          | 0/5013 [00:54<?, ?batch/s, Training Loss=0.529]
# Epoch 2/5:   0%|          | 0/5013 [00:54<?, ?batch/s, Training Loss=0.672]
# Epoch 2/5:   0%|          | 0/5013 [00:54<?, ?batch/s, Training Loss=0.511]
# Epoch 2/5:   0%|          | 0/5013 [00:55<?, ?batch/s, Training Loss=0.107]
# Epoch 2/5:   0%|          | 0/5013 [00:55<?, ?batch/s, Training Loss=0.277]
# Epoch 2/5:   0%|          | 0/5013 [00:55<?, ?batch/s, Training Loss=0.752]
# Epoch 2/5:   0%|          | 0/5013 [00:55<?, ?batch/s, Training Loss=0.207]
# Epoch 2/5:   0%|          | 0/5013 [00:55<?, ?batch/s, Training Loss=0.380]
# Epoch 2/5:   0%|          | 0/5013 [00:55<?, ?batch/s, Training Loss=0.481]
# Epoch 2/5:   0%|          | 0/5013 [00:55<?, ?batch/s, Training Loss=0.521]
# Epoch 2/5:   0%|          | 0/5013 [00:55<?, ?batch/s, Training Loss=0.324]
# Epoch 2/5:   0%|          | 0/5013 [00:56<?, ?batch/s, Training Loss=0.689]
# Epoch 2/5:   0%|          | 0/5013 [00:56<?, ?batch/s, Training Loss=0.267]
# Epoch 2/5:   0%|          | 0/5013 [00:56<?, ?batch/s, Training Loss=0.680]
# Epoch 2/5:   0%|          | 0/5013 [00:56<?, ?batch/s, Training Loss=0.446]
# Epoch 2/5:   0%|          | 0/5013 [00:56<?, ?batch/s, Training Loss=0.678]
# Epoch 2/5:   0%|          | 0/5013 [00:56<?, ?batch/s, Training Loss=0.380]
# Epoch 2/5:   0%|          | 0/5013 [00:56<?, ?batch/s, Training Loss=0.365]
# Epoch 2/5:   0%|          | 0/5013 [00:56<?, ?batch/s, Training Loss=0.510]
# Epoch 2/5:   0%|          | 0/5013 [00:56<?, ?batch/s, Training Loss=0.484]
# Epoch 2/5:   0%|          | 0/5013 [00:57<?, ?batch/s, Training Loss=0.336]
# Epoch 2/5:   0%|          | 0/5013 [00:57<?, ?batch/s, Training Loss=0.356]
# Epoch 2/5:   0%|          | 0/5013 [00:57<?, ?batch/s, Training Loss=0.286]
# Epoch 2/5:   0%|          | 0/5013 [00:57<?, ?batch/s, Training Loss=0.597]
# Epoch 2/5:   0%|          | 0/5013 [00:57<?, ?batch/s, Training Loss=0.374]
# Epoch 2/5:   0%|          | 0/5013 [00:57<?, ?batch/s, Training Loss=0.283]
# Epoch 2/5:   0%|          | 0/5013 [00:57<?, ?batch/s, Training Loss=0.452]
# Epoch 2/5:   0%|          | 0/5013 [00:57<?, ?batch/s, Training Loss=0.373]
# Epoch 2/5:   0%|          | 0/5013 [00:58<?, ?batch/s, Training Loss=0.492]
# Epoch 2/5:   0%|          | 0/5013 [00:58<?, ?batch/s, Training Loss=0.221]
# Epoch 2/5:   0%|          | 0/5013 [00:58<?, ?batch/s, Training Loss=0.453]
# Epoch 2/5:   0%|          | 0/5013 [00:58<?, ?batch/s, Training Loss=0.413]
# Epoch 2/5:   0%|          | 0/5013 [00:58<?, ?batch/s, Training Loss=0.367]
# Epoch 2/5:   0%|          | 0/5013 [00:58<?, ?batch/s, Training Loss=0.531]
# Epoch 2/5:   0%|          | 0/5013 [00:58<?, ?batch/s, Training Loss=0.270]
# Epoch 2/5:   0%|          | 0/5013 [00:58<?, ?batch/s, Training Loss=0.211]
# Epoch 2/5:   0%|          | 0/5013 [00:58<?, ?batch/s, Training Loss=0.541]
# Epoch 2/5:   0%|          | 0/5013 [00:59<?, ?batch/s, Training Loss=0.529]
# Epoch 2/5:   0%|          | 0/5013 [00:59<?, ?batch/s, Training Loss=0.407]
# Epoch 2/5:   0%|          | 0/5013 [00:59<?, ?batch/s, Training Loss=0.165]
# Epoch 2/5:   0%|          | 0/5013 [00:59<?, ?batch/s, Training Loss=0.387]
# Epoch 2/5:   0%|          | 0/5013 [00:59<?, ?batch/s, Training Loss=0.337]
# Epoch 2/5:   0%|          | 0/5013 [00:59<?, ?batch/s, Training Loss=0.260]
# Epoch 2/5:   0%|          | 0/5013 [00:59<?, ?batch/s, Training Loss=0.334]
# Epoch 2/5:   0%|          | 0/5013 [00:59<?, ?batch/s, Training Loss=0.307]
# Epoch 2/5:   0%|          | 0/5013 [01:00<?, ?batch/s, Training Loss=0.310]
# Epoch 2/5:   0%|          | 0/5013 [01:00<?, ?batch/s, Training Loss=0.294]
# Epoch 2/5:   0%|          | 0/5013 [01:00<?, ?batch/s, Training Loss=0.258]
# Epoch 2/5:   0%|          | 0/5013 [01:00<?, ?batch/s, Training Loss=0.384]
# Epoch 2/5:   0%|          | 0/5013 [01:00<?, ?batch/s, Training Loss=0.536]
# Epoch 2/5:   0%|          | 0/5013 [01:00<?, ?batch/s, Training Loss=0.466]
# Epoch 2/5:   0%|          | 0/5013 [01:00<?, ?batch/s, Training Loss=0.422]
# Epoch 2/5:   0%|          | 0/5013 [01:00<?, ?batch/s, Training Loss=0.283]
# Epoch 2/5:   0%|          | 0/5013 [01:01<?, ?batch/s, Training Loss=0.596]
# Epoch 2/5:   0%|          | 0/5013 [01:01<?, ?batch/s, Training Loss=0.522]
# Epoch 2/5:   0%|          | 0/5013 [01:01<?, ?batch/s, Training Loss=0.332]
# Epoch 2/5:   0%|          | 0/5013 [01:01<?, ?batch/s, Training Loss=0.575]
# Epoch 2/5:   0%|          | 0/5013 [01:01<?, ?batch/s, Training Loss=0.191]
# Epoch 2/5:   0%|          | 0/5013 [01:01<?, ?batch/s, Training Loss=0.273]
# Epoch 2/5:   0%|          | 0/5013 [01:01<?, ?batch/s, Training Loss=0.340]
# Epoch 2/5:   0%|          | 0/5013 [01:01<?, ?batch/s, Training Loss=0.307]
# Epoch 2/5:   0%|          | 0/5013 [01:01<?, ?batch/s, Training Loss=0.524]
# Epoch 2/5:   0%|          | 0/5013 [01:02<?, ?batch/s, Training Loss=0.342]
# Epoch 2/5:   0%|          | 0/5013 [01:02<?, ?batch/s, Training Loss=0.291]
# Epoch 2/5:   0%|          | 0/5013 [01:02<?, ?batch/s, Training Loss=0.381]
# Epoch 2/5:   0%|          | 0/5013 [01:02<?, ?batch/s, Training Loss=0.553]
# Epoch 2/5:   0%|          | 0/5013 [01:02<?, ?batch/s, Training Loss=0.284]
# Epoch 2/5:   0%|          | 0/5013 [01:02<?, ?batch/s, Training Loss=0.427]
# Epoch 2/5:   0%|          | 0/5013 [01:02<?, ?batch/s, Training Loss=0.455]
# Epoch 2/5:   0%|          | 0/5013 [01:02<?, ?batch/s, Training Loss=0.420]
# Epoch 2/5:   0%|          | 0/5013 [01:03<?, ?batch/s, Training Loss=0.361]
# Epoch 2/5:   0%|          | 0/5013 [01:03<?, ?batch/s, Training Loss=0.463]
# Epoch 2/5:   0%|          | 0/5013 [01:03<?, ?batch/s, Training Loss=0.800]
# Epoch 2/5:   0%|          | 0/5013 [01:03<?, ?batch/s, Training Loss=0.416]
# Epoch 2/5:   0%|          | 0/5013 [01:03<?, ?batch/s, Training Loss=0.170]
# Epoch 2/5:   0%|          | 0/5013 [01:03<?, ?batch/s, Training Loss=0.500]
# Epoch 2/5:   0%|          | 0/5013 [01:03<?, ?batch/s, Training Loss=0.296]
# Epoch 2/5:   0%|          | 0/5013 [01:03<?, ?batch/s, Training Loss=0.270]
# Epoch 2/5:   0%|          | 0/5013 [01:03<?, ?batch/s, Training Loss=0.480]
# Epoch 2/5:   0%|          | 0/5013 [01:04<?, ?batch/s, Training Loss=0.291]
# Epoch 2/5:   0%|          | 0/5013 [01:04<?, ?batch/s, Training Loss=0.297]
# Epoch 2/5:   0%|          | 0/5013 [01:04<?, ?batch/s, Training Loss=0.500]
# Epoch 2/5:   0%|          | 0/5013 [01:04<?, ?batch/s, Training Loss=0.386]
# Epoch 2/5:   0%|          | 0/5013 [01:04<?, ?batch/s, Training Loss=0.158]
# Epoch 2/5:   0%|          | 0/5013 [01:04<?, ?batch/s, Training Loss=0.394]
# Epoch 2/5:   0%|          | 0/5013 [01:04<?, ?batch/s, Training Loss=0.379]
# Epoch 2/5:   0%|          | 0/5013 [01:04<?, ?batch/s, Training Loss=0.226]
# Epoch 2/5:   0%|          | 0/5013 [01:04<?, ?batch/s, Training Loss=0.383]
# Epoch 2/5:   0%|          | 0/5013 [01:05<?, ?batch/s, Training Loss=0.267]
# Epoch 2/5:   0%|          | 0/5013 [01:05<?, ?batch/s, Training Loss=0.421]
# Epoch 2/5:   0%|          | 0/5013 [01:05<?, ?batch/s, Training Loss=0.382]
# Epoch 2/5:   0%|          | 0/5013 [01:05<?, ?batch/s, Training Loss=0.342]
# Epoch 2/5:   0%|          | 0/5013 [01:05<?, ?batch/s, Training Loss=0.404]
# Epoch 2/5:   0%|          | 0/5013 [01:05<?, ?batch/s, Training Loss=0.314]
# Epoch 2/5:   0%|          | 0/5013 [01:05<?, ?batch/s, Training Loss=0.778]
# Epoch 2/5:   0%|          | 0/5013 [01:05<?, ?batch/s, Training Loss=0.596]
# Epoch 2/5:   0%|          | 0/5013 [01:06<?, ?batch/s, Training Loss=0.467]
# Epoch 2/5:   0%|          | 0/5013 [01:06<?, ?batch/s, Training Loss=0.272]
# Epoch 2/5:   0%|          | 0/5013 [01:06<?, ?batch/s, Training Loss=0.466]
# Epoch 2/5:   0%|          | 0/5013 [01:06<?, ?batch/s, Training Loss=0.334]
# Epoch 2/5:   0%|          | 0/5013 [01:06<?, ?batch/s, Training Loss=0.296]
# Epoch 2/5:   0%|          | 0/5013 [01:06<?, ?batch/s, Training Loss=0.343]
# Epoch 2/5:   0%|          | 0/5013 [01:06<?, ?batch/s, Training Loss=0.343]
# Epoch 2/5:   0%|          | 0/5013 [01:06<?, ?batch/s, Training Loss=0.463]
# Epoch 2/5:   0%|          | 0/5013 [01:06<?, ?batch/s, Training Loss=0.561]
# Epoch 2/5:   0%|          | 0/5013 [01:07<?, ?batch/s, Training Loss=0.230]
# Epoch 2/5:   0%|          | 0/5013 [01:07<?, ?batch/s, Training Loss=0.533]
# Epoch 2/5:   0%|          | 0/5013 [01:07<?, ?batch/s, Training Loss=0.220]
# Epoch 2/5:   0%|          | 0/5013 [01:07<?, ?batch/s, Training Loss=0.268]
# Epoch 2/5:   0%|          | 0/5013 [01:07<?, ?batch/s, Training Loss=0.391]
# Epoch 2/5:   0%|          | 0/5013 [01:07<?, ?batch/s, Training Loss=0.280]
# Epoch 2/5:   0%|          | 0/5013 [01:07<?, ?batch/s, Training Loss=0.255]
# Epoch 2/5:   0%|          | 0/5013 [01:07<?, ?batch/s, Training Loss=0.191]
# Epoch 2/5:   0%|          | 0/5013 [01:08<?, ?batch/s, Training Loss=0.461]
# Epoch 2/5:   0%|          | 0/5013 [01:08<?, ?batch/s, Training Loss=0.446]
# Epoch 2/5:   0%|          | 0/5013 [01:08<?, ?batch/s, Training Loss=0.326]
# Epoch 2/5:   0%|          | 0/5013 [01:08<?, ?batch/s, Training Loss=0.483]
# Epoch 2/5:   0%|          | 0/5013 [01:08<?, ?batch/s, Training Loss=0.524]
# Epoch 2/5:   0%|          | 0/5013 [01:08<?, ?batch/s, Training Loss=0.606]
# Epoch 2/5:   0%|          | 0/5013 [01:08<?, ?batch/s, Training Loss=0.386]
# Epoch 2/5:   0%|          | 0/5013 [01:08<?, ?batch/s, Training Loss=0.465]
# Epoch 2/5:   0%|          | 0/5013 [01:09<?, ?batch/s, Training Loss=0.375]
# Epoch 2/5:   0%|          | 0/5013 [01:09<?, ?batch/s, Training Loss=0.288]
# Epoch 2/5:   0%|          | 0/5013 [01:09<?, ?batch/s, Training Loss=0.534]
# Epoch 2/5:   0%|          | 0/5013 [01:09<?, ?batch/s, Training Loss=0.502]
# Epoch 2/5:   0%|          | 0/5013 [01:09<?, ?batch/s, Training Loss=0.286]
# Epoch 2/5:   0%|          | 0/5013 [01:09<?, ?batch/s, Training Loss=0.314]
# Epoch 2/5:   0%|          | 0/5013 [01:09<?, ?batch/s, Training Loss=0.295]
# Epoch 2/5:   0%|          | 0/5013 [01:09<?, ?batch/s, Training Loss=0.302]
# Epoch 2/5:   0%|          | 0/5013 [01:09<?, ?batch/s, Training Loss=0.328]
# Epoch 2/5:   0%|          | 0/5013 [01:10<?, ?batch/s, Training Loss=0.289]
# Epoch 2/5:   0%|          | 0/5013 [01:10<?, ?batch/s, Training Loss=0.353]
# Epoch 2/5:   0%|          | 0/5013 [01:10<?, ?batch/s, Training Loss=0.268]
# Epoch 2/5:   0%|          | 0/5013 [01:10<?, ?batch/s, Training Loss=0.263]
# Epoch 2/5:   0%|          | 0/5013 [01:10<?, ?batch/s, Training Loss=0.417]
# Epoch 2/5:   0%|          | 0/5013 [01:10<?, ?batch/s, Training Loss=0.572]
# Epoch 2/5:   0%|          | 0/5013 [01:10<?, ?batch/s, Training Loss=0.592]
# Epoch 2/5:   0%|          | 0/5013 [01:10<?, ?batch/s, Training Loss=0.370]
# Epoch 2/5:   0%|          | 0/5013 [01:11<?, ?batch/s, Training Loss=0.543]
# Epoch 2/5:   0%|          | 0/5013 [01:11<?, ?batch/s, Training Loss=0.470]
# Epoch 2/5:   0%|          | 0/5013 [01:11<?, ?batch/s, Training Loss=0.172]
# Epoch 2/5:   0%|          | 0/5013 [01:11<?, ?batch/s, Training Loss=0.587]
# Epoch 2/5:   0%|          | 0/5013 [01:11<?, ?batch/s, Training Loss=0.207]
# Epoch 2/5:   0%|          | 0/5013 [01:11<?, ?batch/s, Training Loss=0.245]
# Epoch 2/5:   0%|          | 0/5013 [01:11<?, ?batch/s, Training Loss=0.311]
# Epoch 2/5:   0%|          | 0/5013 [01:11<?, ?batch/s, Training Loss=0.192]
# Epoch 2/5:   0%|          | 0/5013 [01:11<?, ?batch/s, Training Loss=0.346]
# Epoch 2/5:   0%|          | 0/5013 [01:12<?, ?batch/s, Training Loss=0.766]
# Epoch 2/5:   0%|          | 0/5013 [01:12<?, ?batch/s, Training Loss=0.556]
# Epoch 2/5:   0%|          | 0/5013 [01:12<?, ?batch/s, Training Loss=0.360]
# Epoch 2/5:   0%|          | 0/5013 [01:12<?, ?batch/s, Training Loss=0.326]
# Epoch 2/5:   0%|          | 0/5013 [01:12<?, ?batch/s, Training Loss=0.413]
# Epoch 2/5:   0%|          | 0/5013 [01:12<?, ?batch/s, Training Loss=0.386]
# Epoch 2/5:   0%|          | 0/5013 [01:12<?, ?batch/s, Training Loss=0.226]
# Epoch 2/5:   0%|          | 0/5013 [01:12<?, ?batch/s, Training Loss=0.407]
# Epoch 2/5:   0%|          | 0/5013 [01:13<?, ?batch/s, Training Loss=0.314]
# Epoch 2/5:   0%|          | 0/5013 [01:13<?, ?batch/s, Training Loss=0.433]
# Epoch 2/5:   0%|          | 0/5013 [01:13<?, ?batch/s, Training Loss=0.398]
# Epoch 2/5:   0%|          | 0/5013 [01:13<?, ?batch/s, Training Loss=0.196]
# Epoch 2/5:   0%|          | 0/5013 [01:13<?, ?batch/s, Training Loss=0.212]
# Epoch 2/5:   0%|          | 0/5013 [01:13<?, ?batch/s, Training Loss=0.208]
# Epoch 2/5:   0%|          | 0/5013 [01:13<?, ?batch/s, Training Loss=0.396]
# Epoch 2/5:   0%|          | 0/5013 [01:13<?, ?batch/s, Training Loss=0.320]
# Epoch 2/5:   0%|          | 0/5013 [01:13<?, ?batch/s, Training Loss=0.406]
# Epoch 2/5:   0%|          | 0/5013 [01:14<?, ?batch/s, Training Loss=0.497]
# Epoch 2/5:   0%|          | 0/5013 [01:14<?, ?batch/s, Training Loss=0.398]
# Epoch 2/5:   0%|          | 0/5013 [01:14<?, ?batch/s, Training Loss=0.405]
# Epoch 2/5:   0%|          | 0/5013 [01:14<?, ?batch/s, Training Loss=0.372]
# Epoch 2/5:   0%|          | 0/5013 [01:14<?, ?batch/s, Training Loss=0.317]
# Epoch 2/5:   0%|          | 0/5013 [01:14<?, ?batch/s, Training Loss=0.385]
# Epoch 2/5:   0%|          | 0/5013 [01:14<?, ?batch/s, Training Loss=0.373]
# Epoch 2/5:   0%|          | 0/5013 [01:14<?, ?batch/s, Training Loss=0.400]
# Epoch 2/5:   0%|          | 0/5013 [01:15<?, ?batch/s, Training Loss=0.413]
# Epoch 2/5:   0%|          | 0/5013 [01:15<?, ?batch/s, Training Loss=0.315]
# Epoch 2/5:   0%|          | 0/5013 [01:15<?, ?batch/s, Training Loss=0.527]
# Epoch 2/5:   0%|          | 0/5013 [01:15<?, ?batch/s, Training Loss=0.366]
# Epoch 2/5:   0%|          | 0/5013 [01:15<?, ?batch/s, Training Loss=0.210]
# Epoch 2/5:   0%|          | 0/5013 [01:15<?, ?batch/s, Training Loss=0.241]
# ...
# Epoch 4/5:   0%|          | 0/5013 [09:27<?, ?batch/s, Training Loss=0.403]
# Epoch 4/5:   0%|          | 0/5013 [09:27<?, ?batch/s, Training Loss=0.480]
# Epoch 4/5:   0%|          | 0/5013 [09:27<?, ?batch/s, Training Loss=0.709]
# Epoch 4/5:   0%|          | 0/5013 [09:27<?, ?batch/s, Training Loss=0.586]
# Epoch 4/5:   0%|          | 0/5013 [09:28<?, ?batch/s, Training Loss=0.194]
# Epoch 4/5:   0%|          | 0/5013 [09:28<?, ?batch/s, Training Loss=0.285]
# Epoch 4/5:   0%|          | 0/5013 [09:28<?, ?batch/s, Training Loss=0.708]
# Epoch 4/5:   0%|          | 0/5013 [09:28<?, ?batch/s, Training Loss=0.544]
# Epoch 4/5:   0%|          | 0/5013 [09:28<?, ?batch/s, Training Loss=0.537]
# Epoch 4/5:   0%|          | 0/5013 [09:28<?, ?batch/s, Training Loss=0.321]
# Epoch 4/5:   0%|          | 0/5013 [09:28<?, ?batch/s, Training Loss=0.238]
# Epoch 4/5:   0%|          | 0/5013 [09:28<?, ?batch/s, Training Loss=0.346]
# Epoch 4/5:   0%|          | 0/5013 [09:28<?, ?batch/s, Training Loss=0.187]
# Epoch 4/5:   0%|          | 0/5013 [09:29<?, ?batch/s, Training Loss=0.767]
# Epoch 4/5:   0%|          | 0/5013 [09:29<?, ?batch/s, Training Loss=0.323]
# Epoch 4/5:   0%|          | 0/5013 [09:29<?, ?batch/s, Training Loss=0.156]
# Epoch 4/5:   0%|          | 0/5013 [09:29<?, ?batch/s, Training Loss=0.281]
# Epoch 4/5:   0%|          | 0/5013 [09:29<?, ?batch/s, Training Loss=0.384]
# Epoch 4/5:   0%|          | 0/5013 [09:29<?, ?batch/s, Training Loss=0.444]
# Epoch 4/5:   0%|          | 0/5013 [09:29<?, ?batch/s, Training Loss=0.195]
# Epoch 4/5:   0%|          | 0/5013 [09:29<?, ?batch/s, Training Loss=0.198]
# Epoch 4/5:   0%|          | 0/5013 [09:30<?, ?batch/s, Training Loss=0.332]
# Epoch 4/5:   0%|          | 0/5013 [09:30<?, ?batch/s, Training Loss=0.329]
# Epoch 4/5:   0%|          | 0/5013 [09:30<?, ?batch/s, Training Loss=0.412]
# Epoch 4/5:   0%|          | 0/5013 [09:30<?, ?batch/s, Training Loss=0.523]
# Epoch 4/5:   0%|          | 0/5013 [09:30<?, ?batch/s, Training Loss=0.271]
# Epoch 4/5:   0%|          | 0/5013 [09:30<?, ?batch/s, Training Loss=0.310]
# Epoch 4/5:   0%|          | 0/5013 [09:30<?, ?batch/s, Training Loss=0.372]
# Epoch 4/5:   0%|          | 0/5013 [09:30<?, ?batch/s, Training Loss=0.516]
# Epoch 4/5:   0%|          | 0/5013 [09:31<?, ?batch/s, Training Loss=0.297]
# Epoch 4/5:   0%|          | 0/5013 [09:31<?, ?batch/s, Training Loss=0.422]
# Epoch 4/5:   0%|          | 0/5013 [09:31<?, ?batch/s, Training Loss=0.170]
# Epoch 4/5:   0%|          | 0/5013 [09:31<?, ?batch/s, Training Loss=0.489]
# Epoch 4/5:   0%|          | 0/5013 [09:31<?, ?batch/s, Training Loss=0.366]
# Epoch 4/5:   0%|          | 0/5013 [09:31<?, ?batch/s, Training Loss=0.230]
# Epoch 4/5:   0%|          | 0/5013 [09:31<?, ?batch/s, Training Loss=0.281]
# Epoch 4/5:   0%|          | 0/5013 [09:31<?, ?batch/s, Training Loss=0.196]
# Epoch 4/5:   0%|          | 0/5013 [09:31<?, ?batch/s, Training Loss=0.193]
# Epoch 4/5:   0%|          | 0/5013 [09:32<?, ?batch/s, Training Loss=0.329]
# Epoch 4/5:   0%|          | 0/5013 [09:32<?, ?batch/s, Training Loss=0.320]
# Epoch 4/5:   0%|          | 0/5013 [09:32<?, ?batch/s, Training Loss=0.117]
# Epoch 4/5:   0%|          | 0/5013 [09:32<?, ?batch/s, Training Loss=0.452]
# Epoch 4/5:   0%|          | 0/5013 [09:32<?, ?batch/s, Training Loss=0.212]
# Epoch 4/5:   0%|          | 0/5013 [09:32<?, ?batch/s, Training Loss=0.309]
# Epoch 4/5:   0%|          | 0/5013 [09:32<?, ?batch/s, Training Loss=0.333]
# Epoch 4/5:   0%|          | 0/5013 [09:32<?, ?batch/s, Training Loss=0.663]
# Epoch 4/5:   0%|          | 0/5013 [09:33<?, ?batch/s, Training Loss=0.259]
# Epoch 4/5:   0%|          | 0/5013 [09:33<?, ?batch/s, Training Loss=0.361]
# Epoch 4/5:   0%|          | 0/5013 [09:33<?, ?batch/s, Training Loss=0.191]
# Epoch 4/5:   0%|          | 0/5013 [09:33<?, ?batch/s, Training Loss=0.460]
# Epoch 4/5:   0%|          | 0/5013 [09:33<?, ?batch/s, Training Loss=0.259]
# Epoch 4/5:   0%|          | 0/5013 [09:33<?, ?batch/s, Training Loss=0.364]
# Epoch 4/5:   0%|          | 0/5013 [09:33<?, ?batch/s, Training Loss=0.258]
# Epoch 4/5:   0%|          | 0/5013 [09:33<?, ?batch/s, Training Loss=0.335]
# Epoch 4/5:   0%|          | 0/5013 [09:33<?, ?batch/s, Training Loss=0.517]
# Epoch 4/5:   0%|          | 0/5013 [09:34<?, ?batch/s, Training Loss=0.113]
# Epoch 4/5:   0%|          | 0/5013 [09:34<?, ?batch/s, Training Loss=0.443]
# Epoch 4/5:   0%|          | 0/5013 [09:34<?, ?batch/s, Training Loss=0.457]
# Epoch 4/5:   0%|          | 0/5013 [09:34<?, ?batch/s, Training Loss=0.157]
# Epoch 4/5:   0%|          | 0/5013 [09:34<?, ?batch/s, Training Loss=0.447]
# Epoch 4/5:   0%|          | 0/5013 [09:34<?, ?batch/s, Training Loss=0.444]
# Epoch 4/5:   0%|          | 0/5013 [09:34<?, ?batch/s, Training Loss=0.445]
# Epoch 4/5:   0%|          | 0/5013 [09:34<?, ?batch/s, Training Loss=0.674]
# Epoch 4/5:   0%|          | 0/5013 [09:35<?, ?batch/s, Training Loss=0.400]
# Epoch 4/5:   0%|          | 0/5013 [09:35<?, ?batch/s, Training Loss=0.710]
# Epoch 4/5:   0%|          | 0/5013 [09:35<?, ?batch/s, Training Loss=0.248]
# Epoch 4/5:   0%|          | 0/5013 [09:35<?, ?batch/s, Training Loss=0.334]
# Epoch 4/5:   0%|          | 0/5013 [09:35<?, ?batch/s, Training Loss=0.378]
# Epoch 4/5:   0%|          | 0/5013 [09:35<?, ?batch/s, Training Loss=0.613]
# Epoch 4/5:   0%|          | 0/5013 [09:35<?, ?batch/s, Training Loss=0.386]
# Epoch 4/5:   0%|          | 0/5013 [09:35<?, ?batch/s, Training Loss=0.258]
# Epoch 4/5:   0%|          | 0/5013 [09:35<?, ?batch/s, Training Loss=0.305]
# Epoch 4/5:   0%|          | 0/5013 [09:36<?, ?batch/s, Training Loss=0.292]
# Epoch 4/5:   0%|          | 0/5013 [09:36<?, ?batch/s, Training Loss=0.441]
# Epoch 4/5:   0%|          | 0/5013 [09:36<?, ?batch/s, Training Loss=0.349]
# Epoch 4/5:   0%|          | 0/5013 [09:36<?, ?batch/s, Training Loss=0.374]
# Epoch 4/5:   0%|          | 0/5013 [09:36<?, ?batch/s, Training Loss=0.363]
# Epoch 4/5:   0%|          | 0/5013 [09:36<?, ?batch/s, Training Loss=0.288]
# Epoch 4/5:   0%|          | 0/5013 [09:36<?, ?batch/s, Training Loss=0.331]
# Epoch 4/5:   0%|          | 0/5013 [09:36<?, ?batch/s, Training Loss=0.350]
# Epoch 4/5:   0%|          | 0/5013 [09:37<?, ?batch/s, Training Loss=0.755]
# Epoch 4/5:   0%|          | 0/5013 [09:37<?, ?batch/s, Training Loss=0.371]
# Epoch 4/5:   0%|          | 0/5013 [09:37<?, ?batch/s, Training Loss=0.547]
# Epoch 4/5:   0%|          | 0/5013 [09:37<?, ?batch/s, Training Loss=0.218]
# Epoch 4/5:   0%|          | 0/5013 [09:37<?, ?batch/s, Training Loss=0.280]
# Epoch 4/5:   0%|          | 0/5013 [09:37<?, ?batch/s, Training Loss=0.480]
# Epoch 4/5:   0%|          | 0/5013 [09:37<?, ?batch/s, Training Loss=0.447]
# Epoch 4/5:   0%|          | 0/5013 [09:37<?, ?batch/s, Training Loss=0.435]
# Epoch 4/5:   0%|          | 0/5013 [09:37<?, ?batch/s, Training Loss=0.241]
# Epoch 4/5:   0%|          | 0/5013 [09:38<?, ?batch/s, Training Loss=0.169]
# Epoch 4/5:   0%|          | 0/5013 [09:38<?, ?batch/s, Training Loss=0.368]
# Epoch 4/5:   0%|          | 0/5013 [09:38<?, ?batch/s, Training Loss=0.293]
# Epoch 4/5:   0%|          | 0/5013 [09:38<?, ?batch/s, Training Loss=0.268]
# Epoch 4/5:   0%|          | 0/5013 [09:38<?, ?batch/s, Training Loss=0.239]
# Epoch 4/5:   0%|          | 0/5013 [09:38<?, ?batch/s, Training Loss=0.203]
# Epoch 4/5:   0%|          | 0/5013 [09:38<?, ?batch/s, Training Loss=0.207]
# Epoch 4/5:   0%|          | 0/5013 [09:38<?, ?batch/s, Training Loss=0.147]
# Epoch 4/5:   0%|          | 0/5013 [09:39<?, ?batch/s, Training Loss=0.347]
# Epoch 4/5:   0%|          | 0/5013 [09:39<?, ?batch/s, Training Loss=0.248]
# Epoch 4/5:   0%|          | 0/5013 [09:39<?, ?batch/s, Training Loss=0.663]
# Epoch 4/5:   0%|          | 0/5013 [09:39<?, ?batch/s, Training Loss=0.184]
# Epoch 4/5:   0%|          | 0/5013 [09:39<?, ?batch/s, Training Loss=0.295]
# Epoch 4/5:   0%|          | 0/5013 [09:39<?, ?batch/s, Training Loss=0.391]
# Epoch 4/5:   0%|          | 0/5013 [09:39<?, ?batch/s, Training Loss=0.189]
# Epoch 4/5:   0%|          | 0/5013 [09:39<?, ?batch/s, Training Loss=0.411]
# Epoch 4/5:   0%|          | 0/5013 [09:39<?, ?batch/s, Training Loss=0.356]
# Epoch 4/5:   0%|          | 0/5013 [09:40<?, ?batch/s, Training Loss=0.298]
# Epoch 4/5:   0%|          | 0/5013 [09:40<?, ?batch/s, Training Loss=0.577]
# Epoch 4/5:   0%|          | 0/5013 [09:40<?, ?batch/s, Training Loss=0.696]
# Epoch 4/5:   0%|          | 0/5013 [09:40<?, ?batch/s, Training Loss=0.188]
# Epoch 4/5:   0%|          | 0/5013 [09:40<?, ?batch/s, Training Loss=0.386]
# Epoch 4/5:   0%|          | 0/5013 [09:40<?, ?batch/s, Training Loss=0.304]
# Epoch 4/5:   0%|          | 0/5013 [09:40<?, ?batch/s, Training Loss=0.304]
# Epoch 4/5:   0%|          | 0/5013 [09:40<?, ?batch/s, Training Loss=0.442]
# Epoch 4/5:   0%|          | 0/5013 [09:41<?, ?batch/s, Training Loss=0.263]
# Epoch 4/5:   0%|          | 0/5013 [09:41<?, ?batch/s, Training Loss=0.279]
# Epoch 4/5:   0%|          | 0/5013 [09:41<?, ?batch/s, Training Loss=0.317]
# Epoch 4/5:   0%|          | 0/5013 [09:41<?, ?batch/s, Training Loss=0.401]
# Epoch 4/5:   0%|          | 0/5013 [09:41<?, ?batch/s, Training Loss=0.232]
# Epoch 4/5:   0%|          | 0/5013 [09:41<?, ?batch/s, Training Loss=0.339]
# Epoch 4/5:   0%|          | 0/5013 [09:41<?, ?batch/s, Training Loss=0.442]
# Epoch 4/5:   0%|          | 0/5013 [09:41<?, ?batch/s, Training Loss=0.303]
# Epoch 4/5:   0%|          | 0/5013 [09:41<?, ?batch/s, Training Loss=0.143]
# Epoch 4/5:   0%|          | 0/5013 [09:42<?, ?batch/s, Training Loss=0.360]
# Epoch 4/5:   0%|          | 0/5013 [09:42<?, ?batch/s, Training Loss=0.338]
# Epoch 4/5:   0%|          | 0/5013 [09:42<?, ?batch/s, Training Loss=0.262]
# Epoch 4/5:   0%|          | 0/5013 [09:42<?, ?batch/s, Training Loss=0.466]
# Epoch 4/5:   0%|          | 0/5013 [09:42<?, ?batch/s, Training Loss=0.538]
# Epoch 4/5:   0%|          | 0/5013 [09:42<?, ?batch/s, Training Loss=0.637]
# Epoch 4/5:   0%|          | 0/5013 [09:42<?, ?batch/s, Training Loss=0.230]
# Epoch 4/5:   0%|          | 0/5013 [09:42<?, ?batch/s, Training Loss=0.253]
# Epoch 4/5:   0%|          | 0/5013 [09:43<?, ?batch/s, Training Loss=0.331]
# Epoch 4/5:   0%|          | 0/5013 [09:43<?, ?batch/s, Training Loss=0.375]
# Epoch 4/5:   0%|          | 0/5013 [09:43<?, ?batch/s, Training Loss=0.407]
# Epoch 4/5:   0%|          | 0/5013 [09:43<?, ?batch/s, Training Loss=0.192]
# Epoch 4/5:   0%|          | 0/5013 [09:43<?, ?batch/s, Training Loss=0.440]
# Epoch 4/5:   0%|          | 0/5013 [09:43<?, ?batch/s, Training Loss=0.564]
# Epoch 4/5:   0%|          | 0/5013 [09:43<?, ?batch/s, Training Loss=0.292]
# Epoch 4/5:   0%|          | 0/5013 [09:43<?, ?batch/s, Training Loss=0.485]
# Epoch 4/5:   0%|          | 0/5013 [09:43<?, ?batch/s, Training Loss=0.185]
# Epoch 4/5:   0%|          | 0/5013 [09:44<?, ?batch/s, Training Loss=0.361]
# Epoch 4/5:   0%|          | 0/5013 [09:44<?, ?batch/s, Training Loss=0.453]
# Epoch 4/5:   0%|          | 0/5013 [09:44<?, ?batch/s, Training Loss=0.244]
# Epoch 4/5:   0%|          | 0/5013 [09:44<?, ?batch/s, Training Loss=0.159]
# Epoch 4/5:   0%|          | 0/5013 [09:44<?, ?batch/s, Training Loss=0.327]
# Epoch 4/5:   0%|          | 0/5013 [09:44<?, ?batch/s, Training Loss=0.439]
# Epoch 4/5:   0%|          | 0/5013 [09:44<?, ?batch/s, Training Loss=0.164]
# Epoch 4/5:   0%|          | 0/5013 [09:44<?, ?batch/s, Training Loss=0.585]
# Epoch 4/5:   0%|          | 0/5013 [09:45<?, ?batch/s, Training Loss=0.342]
# Epoch 4/5:   0%|          | 0/5013 [09:45<?, ?batch/s, Training Loss=0.436]
# Epoch 4/5:   0%|          | 0/5013 [09:45<?, ?batch/s, Training Loss=0.277]
# Epoch 4/5:   0%|          | 0/5013 [09:45<?, ?batch/s, Training Loss=0.409]
# Epoch 4/5:   0%|          | 0/5013 [09:45<?, ?batch/s, Training Loss=0.578]
# Epoch 4/5:   0%|          | 0/5013 [09:45<?, ?batch/s, Training Loss=0.338]
# Epoch 4/5:   0%|          | 0/5013 [09:45<?, ?batch/s, Training Loss=0.254]
# Epoch 4/5:   0%|          | 0/5013 [09:45<?, ?batch/s, Training Loss=0.616]
# Epoch 4/5:   0%|          | 0/5013 [09:45<?, ?batch/s, Training Loss=0.289]
# Epoch 4/5:   0%|          | 0/5013 [09:46<?, ?batch/s, Training Loss=0.205]
# Epoch 4/5:   0%|          | 0/5013 [09:46<?, ?batch/s, Training Loss=0.165]
# Epoch 4/5:   0%|          | 0/5013 [09:46<?, ?batch/s, Training Loss=0.261]
# Epoch 4/5:   0%|          | 0/5013 [09:46<?, ?batch/s, Training Loss=0.586]
# Epoch 4/5:   0%|          | 0/5013 [09:46<?, ?batch/s, Training Loss=0.215]
# Epoch 4/5:   0%|          | 0/5013 [09:46<?, ?batch/s, Training Loss=0.242]
# Epoch 4/5:   0%|          | 0/5013 [09:46<?, ?batch/s, Training Loss=0.393]
# Epoch 4/5:   0%|          | 0/5013 [09:46<?, ?batch/s, Training Loss=0.284]
# Epoch 4/5:   0%|          | 0/5013 [09:47<?, ?batch/s, Training Loss=0.431]
# Epoch 4/5:   0%|          | 0/5013 [09:47<?, ?batch/s, Training Loss=0.235]
# Epoch 4/5:   0%|          | 0/5013 [09:47<?, ?batch/s, Training Loss=0.292]
# Epoch 4/5:   0%|          | 0/5013 [09:47<?, ?batch/s, Training Loss=0.505]
# Epoch 4/5:   0%|          | 0/5013 [09:47<?, ?batch/s, Training Loss=0.213]
# Epoch 4/5:   0%|          | 0/5013 [09:47<?, ?batch/s, Training Loss=0.191]
# Epoch 4/5:   0%|          | 0/5013 [09:47<?, ?batch/s, Training Loss=0.364]
# Epoch 4/5:   0%|          | 0/5013 [09:47<?, ?batch/s, Training Loss=0.405]
# Epoch 4/5:   0%|          | 0/5013 [09:47<?, ?batch/s, Training Loss=0.369]
# Epoch 4/5:   0%|          | 0/5013 [09:48<?, ?batch/s, Training Loss=0.441]
# Epoch 4/5:   0%|          | 0/5013 [09:48<?, ?batch/s, Training Loss=0.564]
# Epoch 4/5:   0%|          | 0/5013 [09:48<?, ?batch/s, Training Loss=0.258]
# Epoch 4/5:   0%|          | 0/5013 [09:48<?, ?batch/s, Training Loss=0.126]
# Epoch 4/5:   0%|          | 0/5013 [09:48<?, ?batch/s, Training Loss=0.367]
# Epoch 4/5:   0%|          | 0/5013 [09:48<?, ?batch/s, Training Loss=0.385]
# Epoch 4/5:   0%|          | 0/5013 [09:48<?, ?batch/s, Training Loss=0.211]
# Epoch 4/5:   0%|          | 0/5013 [09:48<?, ?batch/s, Training Loss=0.246]
# Epoch 4/5:   0%|          | 0/5013 [09:49<?, ?batch/s, Training Loss=0.358]
# Epoch 4/5:   0%|          | 0/5013 [09:49<?, ?batch/s, Training Loss=0.285]
# Epoch 4/5:   0%|          | 0/5013 [09:49<?, ?batch/s, Training Loss=0.334]
# Epoch 4/5:   0%|          | 0/5013 [09:49<?, ?batch/s, Training Loss=0.320]
# Epoch 4/5:   0%|          | 0/5013 [09:49<?, ?batch/s, Training Loss=0.729]
# Epoch 4/5:   0%|          | 0/5013 [09:49<?, ?batch/s, Training Loss=0.331]
# Epoch 4/5:   0%|          | 0/5013 [09:49<?, ?batch/s, Training Loss=0.337]
# Epoch 4/5:   0%|          | 0/5013 [09:49<?, ?batch/s, Training Loss=0.414]
# Epoch 4/5:   0%|          | 0/5013 [09:49<?, ?batch/s, Training Loss=0.709]
# Epoch 4/5:   0%|          | 0/5013 [09:50<?, ?batch/s, Training Loss=0.383]
# Epoch 4/5:   0%|          | 0/5013 [09:50<?, ?batch/s, Training Loss=0.313]
# Epoch 4/5:   0%|          | 0/5013 [09:50<?, ?batch/s, Training Loss=0.193]
# Epoch 4/5:   0%|          | 0/5013 [09:50<?, ?batch/s, Training Loss=0.386]
# Epoch 4/5:   0%|          | 0/5013 [09:50<?, ?batch/s, Training Loss=0.559]
# Epoch 4/5:   0%|          | 0/5013 [09:50<?, ?batch/s, Training Loss=0.271]
# Epoch 4/5:   0%|          | 0/5013 [09:50<?, ?batch/s, Training Loss=0.464]
# Epoch 4/5:   0%|          | 0/5013 [09:50<?, ?batch/s, Training Loss=0.258]
# Epoch 4/5:   0%|          | 0/5013 [09:51<?, ?batch/s, Training Loss=0.152]
# Epoch 4/5:   0%|          | 0/5013 [09:51<?, ?batch/s, Training Loss=0.530]
# Epoch 4/5:   0%|          | 0/5013 [09:51<?, ?batch/s, Training Loss=0.299]
# Epoch 4/5:   0%|          | 0/5013 [09:51<?, ?batch/s, Training Loss=0.209]
# Epoch 4/5:   0%|          | 0/5013 [09:51<?, ?batch/s, Training Loss=0.317]
# Epoch 4/5:   0%|          | 0/5013 [09:51<?, ?batch/s, Training Loss=0.333]
# Epoch 4/5:   0%|          | 0/5013 [09:51<?, ?batch/s, Training Loss=0.222]
# Epoch 4/5:   0%|          | 0/5013 [09:51<?, ?batch/s, Training Loss=0.238]
# Epoch 4/5, Training loss: 0.3580485860994184
# Epoch 4/5:   0%|          | 0/5013 [09:52<?, ?batch/s, Training Loss=0.238]
# Epoch 5/5:   0%|          | 0/5013 [09:29<?, ?batch/s, Training Loss=0.314]
# Epoch 5/5, Training loss: 0.36002266396014676

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(8, 6))
plt.plot(epoch_numbers_5, train_loss_values_5, color='blue', linestyle='-', marker='o', linewidth=2)
plt.title("Training Loss vs Epoch (5 epochs)", fontsize=18)
plt.xlabel("Epoch", fontsize=14)
plt.ylabel("Training Loss", fontsize=14)
plt.tick_params(labelsize=12)
plt.grid(alpha=0.3)
plt.show()

# %%
#Epoch - 10
# from tqdm import tqdm
# train_loss_values_10 = []
# epoch_numbers_10 = []

# for epoch in range(epochs_10):
#     model.train()
#     train_loss = 0
#     progress_bar = tqdm(train_dataloader, desc=f"Epoch {epoch + 1}/{epochs_10}", unit="batch")
#     for batch in train_dataloader:
#         input_ids, attention_masks, labels = batch
#         input_ids = input_ids.to(device)
#         attention_masks = attention_masks.to(device)
#         labels = labels.to(device)
#         model.zero_grad()
#         outputs = model(input_ids, attention_mask=attention_masks, labels=labels)
#         loss = outputs[0]
#         train_loss += loss.item()
#         loss.backward()
#         optimizer.step()
#         scheduler.step()
#         progress_bar.set_postfix({'Training Loss': '{:.3f}'.format(loss.item())})
#     avg_train_loss = train_loss / len(train_dataloader)
#     train_loss_values_10.append(avg_train_loss)
#     epoch_numbers_10.append(epoch+1)
#     print(f"Epoch {epoch + 1}/{epochs_10}, Training loss: {avg_train_loss}")

# %%
# plt.figure(figsize=(8, 6))
# plt.plot(epoch_numbers_10, train_loss_values_10, color='blue', linestyle='-', marker='o', linewidth=2)
# plt.title("Training Loss vs Epoch (10 epochs)", fontsize=18)
# plt.xlabel("Epoch", fontsize=14)
# plt.ylabel("Training Loss", fontsize=14)
# plt.tick_params(labelsize=12)
# plt.grid

# %%
from sklearn.metrics import f1_score
from sklearn.metrics import classification_report
model.eval()
predictions, true_labels = [], []

with torch.no_grad():
    for batch in test_dataloader:
        input_ids, attention_masks, labels = batch
        input_ids = input_ids.to(device)
        attention_masks = attention_masks.to(device)
        labels = labels.to(device)
        outputs = model(input_ids, attention_mask=attention_masks, labels=labels)
        loss, logits = outputs[:2]
        logits = logits.detach().cpu().numpy()
        label_ids = labels.to('cpu').numpy()
        predictions.extend(np.argmax(logits, axis=1).flatten())
        true_labels.extend(label_ids.flatten())

accuracy = accuracy_score(true_labels, predictions)
f1 = f1_score(true_labels, predictions, average='weighted')

# Compute classification report
report = classification_report(true_labels, predictions)

print(f"Accuracy on test dataset: {accuracy}")
print(f"F1 score on test dataset: {f1}")
print("Classification Report:")
print(report)
# Out:
# Accuracy on test dataset: 0.7604869929494492
# F1 score on test dataset: 0.7571582092596841
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.83      0.81      0.82      9589
#            1       0.55      0.48      0.51      3839
#            2       0.54      0.52      0.53      4793
#            3       0.60      0.58      0.59      9193
#            4       0.85      0.89      0.87     26057
#
#     accuracy                           0.76     53471
#    macro avg       0.67      0.66      0.66     53471
# weighted avg       0.75      0.76      0.76     53471

# %%
sentiment_mapping = {
    0: "Negative",
    1: "Neutral",
    2: "Positive",
    3: "Very Positive",
    4: "Extremely Positive"
}

# %%
import pandas as pd

data = {'Drug': [], 'Review': [], 'Sentiment': []}

for i in range(len(predictions)):
    sentiment = sentiment_mapping[predictions[i]]
    drug = df_test.iloc[i]['drugName']
    review = df_test.iloc[i]['review']
    data['Drug'].append(drug)
    data['Review'].append(review)
    data['Sentiment'].append(sentiment)

df_results = pd.DataFrame(data)
print(df_results)
# Out:
#                             Drug  \
# 0                    Mirtazapine
# 1                     Mesalamine
# 2                        Bactrim
# 3                       Contrave
# 4                Cyclafem 1 / 35
# ...                          ...
# 53466                  Clonidine
# 53467        Ortho Tri-Cyclen Lo
# 53468                  Adapalene
# 53469  Piperacillin / tazobactam
# 53470                    Silenor
#
#                                                   Review           Sentiment
# 0      "I&#039;ve tried a few antidepressants over th...  Extremely Positive
# 1      "My son has Crohn&#039;s disease and has done ...  Extremely Positive
# 2                          "Quick reduction of symptoms"  Extremely Positive
# 3      "Contrave combines drugs that were used for al...  Extremely Positive
# 4      "I have been on this birth control for one cyc...  Extremely Positive
# ...                                                  ...                 ...
# 53466  "I have a 8 year old son with ADHD. He is extr...       Very Positive
# 53467  "I have been on this pill for exactly 1 year m...       Very Positive
# 53468  "I&#039;m currently on my 5th week of Differin...  Extremely Positive
# 53469  "I got this through my IV while in the hospita...            Negative
# 53470  "I have had depression, anxiety and insomnia i...  Extremely Positive
#
# [53471 rows x 3 columns]

# %%
def best_drug_for_condition(condition, df):
    condition_df = df[df['condition'] == condition]
    if condition_df.empty:
        print(f"No data found for {condition}.")
        return None
    condition_df = condition_df.groupby('drugName')['sentiment'].mean().reset_index()
    best_sentiment = condition_df['sentiment'].idxmax()
    best_drug = condition_df.loc[best_sentiment]['drugName']
    return best_drug
# Out:
# Enter a medical condition: Birth Control
# The recommended drug for Birth Control is: Balziva

# %%
while True:
  condition = input("Enter a medical condition (press 1 to exit): ")
  if condition == '1':
    break
  best_drug = best_drug_for_condition(condition, df_test)
  if best_drug is not None:
    print(f"The recommended drug for {condition} is: {best_drug}")
  else:
    print("No recommendation available for the given condition.")
  print()
# Out:
# Enter a medical condition (press 1 to exit): Birth Control
# The recommended drug for Birth Control is: Balziva
#
# Enter a medical condition (press 1 to exit): 1
